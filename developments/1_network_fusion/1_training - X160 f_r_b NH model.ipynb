# %%
# !nvidia-smi
# Out:
# Mon Jan 20 14:06:59 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.26       Driver Version: 430.26       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  Off  | 00000000:1D:00.0 Off |                  N/A |
# | 27%   27C    P8    13W / 250W |     10MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  Off  | 00000000:1E:00.0 Off |                  N/A |
# | 27%   27C    P8     5W / 250W |  10927MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  Off  | 00000000:1F:00.0 Off |                  N/A |
# | 35%   55C    P2   124W / 250W |   4333MiB / 11019MiB |    100%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 208...  Off  | 00000000:20:00.0 Off |                  N/A |
# | 30%   47C    P2   114W / 250W |   2591MiB / 11019MiB |     99%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce RTX 208...  Off  | 00000000:21:00.0 Off |                  N/A |
# | 27%   31C    P2    64W / 250W |  11014MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce RTX 208...  Off  | 00000000:22:00.0 Off |                  N/A |
# | 27%   29C    P0    74W / 250W |     10MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce RTX 208...  Off  | 00000000:23:00.0 Off |                  N/A |
# | 27%   28C    P8    17W / 250W |     10MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  GeForce RTX 208...  Off  | 00000000:24:00.0 Off |                  N/A |
# | 27%   27C    P8     1W / 250W |  10929MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    1      2716      C   /usr/bin/python3                           10917MiB |
# |    2     13246      C   /usr/bin/python3                             867MiB |
# |    2     13261      C   /usr/bin/python3                             863MiB |
# |    2     13276      C   /usr/bin/python3                             867MiB |
# |    2     13555      C   /usr/bin/python3                             865MiB |
# |    2     15177      C   /usr/bin/python3                             861MiB |
# |    3     15061      C   /usr/bin/python3                             863MiB |
# |    3     15486      C   /usr/bin/python3                             859MiB |
# |    3     15613      C   /usr/bin/python3                             859MiB |
# |    4      9736      C   /usr/bin/python3                           10655MiB |
# |    4     15885      C   /usr/bin/python3                             349MiB |
# |    7     46534      C   /usr/bin/python3                           10919MiB |
# +-----------------------------------------------------------------------------+

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="5"

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import time, datetime

import sys
sys.path.append('/mnt/disk1/project/SMhospital/capsule/ce_packages')
from ce_utils import load_path, train_valid_split, damped_exp_LR, load_random_minibatch, shuffle
from ce_utils import training_history
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Load Data

# %%
from itertools import product
import glob

def target_preprocessings(phase_a_switch = [1, 1, 1], phase_b_switch = True, mode = 'load'):
    """
    phase_a_switch = [1, 1, 1], [0, 0 ,1], [1, 1, 0].... 
    that means [flip, rotate, blur_sharp]
    """
    phase0 = ['_c']
    phase1 = {1: ['-', 'f'], 0: ['-']}
    phase2 = {1: ['-', 'r1', 'r2', 'r3'], 0: ['-']}
    phase3 = {1: ['-', 'ab', 'mb', 'eh'], 0: ['-']}
    phase4 = ['s_-30_v_30', 's_-30_v_-30', 's_30_v_-30', 's_30_v_30']
    
    if mode == 'load':
        phase_a_items = [phase1[phase_a_switch[0]], phase2[phase_a_switch[1]], phase3[phase_a_switch[2]]]
    elif mode == 'preprocessing':
        phase_a_items = [phase0, phase1[phase_a_switch[0]], phase2[phase_a_switch[1]], phase3[phase_a_switch[2]]]
    
    phase_a = []
    for i in list(product(*phase_a_items)):
        phase_a.append('_'.join(i))

    if not phase_b_switch != True:
        phase_b = []
        for i in list(product(*[phase_a, phase4])):
            phase_b.append('_'.join(i))
        return list(np.hstack([phase_a, phase_b]))
    else:
        return phase_a 

class ce_load_dataset:
    def __init__(self, phase, data, pre_a, pre_b, img_ch = 'bgr', ext_name = True):
        self.phase = phase        # 'train' or 'test'
        self.data = data          # 'sm', 'sm_core', 'sm_v2', 'sm_x160', ...
        self.pre_a = pre_a        # [1, 1, 1], [0, 0 ,1], [1, 1, 0].... 
        self.pre_b = pre_b        # True or False
        self.img_ch = img_ch      # 'bgr', 'rgb', and 'hsv'
        self.ext_name = ext_name  # True or False

    def load_path(self, cls, les, data_dir = '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed'):
        """
        phase = 'train', 'test'
        cls: [les]  
          'n': ['neg']
          'h': ['redspot', 'angio', 'active'], 
          'd': ['ero', 'ulc', 'str'],
          'p': ['amp', 'lym', 'tum']}
        pre_a[0] must be 0
        """
        lesions = dict(neg = 'negative', 
                       redspot = 'red_spot', angio = 'angioectasia', active = 'active_bleeding', 
                       ero = 'erosion', ulcer = 'ulcer', str = 'stricture', 
                       amp = 'ampulla_of_vater', lym = 'lymphoid_follicles', tum = 'small_bowel_tumor')
        classes = dict(n = 'negative', h = 'hemorrhagic', d = 'depressed', p = 'protruded')

        path = os.path.join(data_dir, self.data, self.phase, classes[cls], lesions[les])
        pathlist = glob.glob(path + '/*.jpg')
        if self.pre_b != True:
            path_in_phase = []
            for p in pathlist:
                name = os.path.basename(p)
#                 print(target_preprocessings(self.pre_a, self.pre_b))
                if (name.split('c_')[-1])[:-4] in target_preprocessings(self.pre_a, self.pre_b):
                    path_in_phase.append(p)   
            return np.asarray(path_in_phase)
        else:
            return np.asarray(pathlist)

    def load_image_from_path(self, pathlist,image_ch = 'bgr', extract_name = False):
        data = []
        for i in pathlist:
            temp = cv2.imread(i)
            if image_ch == 'bgr':
                pass
            elif image_ch == 'rgb':
                temp = cv2.cvtColor(temp, cv2.COLOR_BGR2RGB)
            elif image_ch == 'hsv':
                temp = cv2.cvtColor(temp, cv2.COLOR_BGR2HSV)
            data.append(temp)
        if extract_name != False:
            name = []
            for i in pathlist:
                name.append(os.path.basename(i))
            return np.asarray(data), np.asarray(name)
        else:
            return np.asarray(data) 

    def load_data(self, cls, les):
        pathlist = self.load_path(cls, les)
        return  self.load_image_from_path(pathlist, image_ch = self.img_ch, extract_name = self.ext_name)

# %%
ce = ce_load_dataset(phase = 'train', data = 'sm_x160', pre_a = [1, 1, 1], pre_b = False)

# %%
neg_path = ce.load_path('n', 'neg')
redspot_path = ce.load_path('h', 'redspot')
angio_path = ce.load_path('h', 'angio')
active_path = ce.load_path('h', 'active')
# ero_path = ce.load_path('d', 'ero')
# ulcer_path = ce.load_path('d', 'ulcer')
# str_path = ce.load_path('d', 'str')

print("negative:",neg_path.shape)
print("red spot:",redspot_path.shape)
print("angioectasia:",angio_path.shape)
print("active_bleeding:",active_path.shape)
# print("erosion:",ero_path.shape)
# print("ulcer:",ulcer_path.shape)
# print("stricture:",str_path.shape)
# Out:
# negative: (203424,)
# red spot: (18592,)
# angioectasia: (640,)
# active_bleeding: (13248,)

# %%
angio_path
# Out:
# array(['/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-06___2032944__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-20___2032972__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/실한___02-12-31___2032994__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-17___2085089__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/연박___09-26-28___2085111__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-11-34___2003337__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-13-31___2003593__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-08___2003801__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-14-31___2003925__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-15-15___2004160__c_f_r3_ab.jpg',
# ...
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-25-59___2006917__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-25-59___2006917__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-25-59___2006917__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-25-59___2006917__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-25-59___2006917__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-25-59___2006917__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-25-59___2006917__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-25-59___2006917__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-25-59___2006917__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-25-59___2006917__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-27-24___2007362__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-30-39___2008347__c_f_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_-_r3_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_-_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_-_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_-_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r1_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r1_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r1_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r2_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r2_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r2_eh.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r3_ab.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r3_mb.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160/train/hemorrhagic/angioectasia/충이___00-31-22___2008552__c_f_r3_eh.jpg'],
#       dtype='<U140')

# %%
neg_train_path, neg_valid_path = train_valid_split(neg_path)
redspot_train_path, redspot_valid_path = train_valid_split(redspot_path)
angio_train_path, angio_valid_path = train_valid_split(angio_path)
active_train_path, active_valid_path = train_valid_split(active_path)
# ero_train_path, ero_valid_path = train_valid_split(ero_path)
# ulcer_train_path, ulcer_valid_path = train_valid_split(ulcer_path)
# str_train_path, str_valid_path = train_valid_split(str_path)

print("negative:", neg_train_path.shape, neg_valid_path.shape)
print("red spot:", redspot_train_path.shape, redspot_valid_path.shape)
print("angioectasia:", angio_train_path.shape, angio_valid_path.shape)
print("active bleeding:", active_train_path.shape, active_valid_path.shape)
# print("erosion:", ero_train_path.shape, ero_valid_path.shape)
# print("ulcer:", ulcer_train_path.shape, ulcer_valid_path.shape)
# print("stricture:", str_train_path.shape, str_valid_path.shape)
# Out:
# negative: (172910,) (25973,)
# red spot: (15803,) (2358,)
# angioectasia: (544,) (81,)
# active bleeding: (11260,) (1705,)

# %% [markdown]
# # Model

# %%
input_h = 512
input_w = 512
input_ch = 3

k_chs = [16, 16, 16, 32, 32, 32, 64]
n_conv_block = len(k_chs)
n_hid_node = [100, 50]
n_hid_layer = len(n_hid_node)
n_output = 2

# %%
class CE_cnn:
    def __init__(self, k_chs, n_conv_block, n_hid_node, n_hid_layer, n_output):
        self.k_chs = k_chs
        self.n_conv_block = n_conv_block
        self.n_hid_node = n_hid_node
        self.n_hid_layer = n_hid_layer
        self.n_output = n_output
    def conv_block(self, x, k_chs, n_conv_block):
        for i in range(1, n_conv_block + 1):
            if i == 1:
                conv = tf.layers.conv2d(inputs = x, filters = k_chs[i-1], kernel_size = [3, 3], padding = "SAME", 
                                        activation= tf.nn.relu, name = 'block_{}_conv_1'.format(i))
            else:
                conv = tf.layers.conv2d(inputs = conv, filters = k_chs[i-1], kernel_size = [3, 3], padding = "SAME", 
                                        activation= tf.nn.relu, name = 'block_{}_conv_1'.format(i))
            conv = tf.layers.conv2d(inputs = conv, filters = k_chs[i-1], kernel_size = [3, 3], padding = "SAME", 
                                    activation= tf.nn.relu, name = 'block_{}_conv_2'.format(i))
            conv = tf.layers.max_pooling2d(inputs = conv, pool_size = [2, 2], strides = 2, name = 'block_{}_maxp'.format(i))
        return conv
    def fc_layers(self, x, n_hid_node, n_hid_layer, n_output):
        hidden = tf.layers.flatten(x)
        for i in range(1, n_hid_layer + 1):
            hidden = tf.layers.dense(inputs = hidden, units = n_hid_node[i-1],activation = tf.nn.relu, name = 'fc_{}'.format(i))
            hidden = tf.layers.dropout(hidden, rate = 0.3, training = is_training)
        score = tf.layers.dense(inputs = hidden, units = n_output, name = 'score')
        return score
    
    def inf(self, x):
        conv = self.conv_block(x, self.k_chs, self.n_conv_block)
        score = self.fc_layers(conv, self.n_hid_node, self.n_hid_layer, self.n_output)
        return score

# %%
tf.reset_default_graph()

x = tf.placeholder(tf.float32, [None, input_h, input_w, input_ch], name = 'img')
y = tf.placeholder(tf.float32, [None, n_output], name = 'label')
#rate = tf.placeholder(tf.float32, name = 'rate') # tf.layers.dropout용 얼만큼 드랍아웃할건지
is_training = tf.placeholder(tf.bool, name = 'is_training')
LR = tf.placeholder(tf.float32)

model = CE_cnn(k_chs, n_conv_block, n_hid_node, n_hid_layer, n_output)
score = model.inf(x)
loss = tf.losses.softmax_cross_entropy(onehot_labels=y, logits=score)
loss = tf.reduce_mean(loss)

# update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
# with tf.control_dependencies(update_ops):
#     optm = tf.train.AdamOptimizer(learning_rate=lr).minimize(loss)
optm = tf.train.AdamOptimizer(LR).minimize(loss)

saver = tf.train.Saver()
sess = tf.Session()

init = tf.global_variables_initializer()
sess.run(init)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0120 14:08:41.752772 140343832446720 deprecation.py:323] From <ipython-input-9-147423120551>:12: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# W0120 14:08:41.758657 140343832446720 deprecation.py:506] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0120 14:08:41.993582 140343832446720 deprecation.py:323] From <ipython-input-9-147423120551>:18: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# W0120 14:08:42.320659 140343832446720 deprecation.py:323] From <ipython-input-9-147423120551>:21: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# W0120 14:08:42.534419 140343832446720 deprecation.py:323] From <ipython-input-9-147423120551>:23: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0120 14:08:42.927724 140343832446720 deprecation.py:323] From <ipython-input-9-147423120551>:24: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# W0120 14:08:43.064059 140343832446720 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# # Training

# %% [markdown]
# damped_exp_LR(30000, alpha = 0.00005) <br>
# n_batch (per class) = 50  <br>
# cal_interval = 10 <br>
# prt_interval = 100 <br>

# %%
h_train_path = np.hstack([redspot_train_path, angio_train_path, active_train_path])
h_valid_path = np.hstack([redspot_valid_path, angio_valid_path, active_valid_path])

a_train_path = shuffle(h_train_path, None)
a_valid_path = shuffle(h_valid_path, None)

# %%
damped_exp_LR
# Out:
# <function ce_utils.damped_exp_LR(n_iter, f=20, A=0.0005, alpha=0.0002, gamma=0.1)>

# %%
D_lr = damped_exp_LR(30000, alpha = 0.00005)

plt.plot(D_lr)

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

n_iter = 0
n_batch = 50
cal_interval = 10
prt_interval = 100
 
early_stopping = False
accr_train, accr_valid, loss_train, loss_valid = [], [], [], []
hist = training_history(accr_train, accr_valid, loss_train, loss_valid)
hist.table()

start_time = time.time()

while True:
    neg_train_x, neg_train_y = load_random_minibatch(neg_train_path, cls = 0, batch_size = n_batch)
    a_train_x, a_train_y = load_random_minibatch(a_train_path, cls = 1, batch_size = n_batch)
    train_x = np.vstack([neg_train_x, a_train_x])
    train_y = np.vstack([neg_train_y, a_train_y])
    train_x, train_y = shuffle(train_x, train_y)
    
    sess.run(optm, feed_dict = {'img:0': train_x, 'label:0': train_y, 'is_training:0' :1, LR: D_lr[n_iter]})
    n_iter += 1
    
    if n_iter % cal_interval == 0:
        c, p = sess.run([loss, score], feed_dict = {'img:0': train_x, 'label:0': train_y, 'is_training:0' :0})

        p = np.argmax(p, axis = 1)
        l = np.argmax(train_y, axis = 1)
        a = np.mean(np.equal(p, l))
        
        neg_valid_x, neg_valid_y = load_random_minibatch(neg_valid_path, cls = 0, batch_size = n_batch)
        a_valid_x, a_valid_y = load_random_minibatch(a_valid_path, cls = 1, batch_size = n_batch)
        valid_x = np.vstack([neg_valid_x, a_valid_x])
        valid_y = np.vstack([neg_valid_y, a_valid_y])
        
        c_valid, p_valid = sess.run([loss, score], feed_dict = {'img:0': valid_x, 'label:0': valid_y, 'is_training:0' :0})

        p_valid = np.argmax(p_valid, axis = 1)
        l_valid = np.argmax(valid_y, axis = 1)
        a_valid = np.mean(np.equal(p_valid, l_valid))

        accr_valid.append(a_valid)
        loss_valid.append(c_valid)
        accr_train.append(a)
        loss_train.append(c)

        if n_iter % prt_interval == 0:
            hist.prt_evl(n_iter)

        if loss_valid[-1] == np.min(loss_valid):
            now = datetime.datetime.now()
            nowDatetime = now.strftime('%y%m%d%H%M')
            model_name = 'X160_frb_NH_{0}_{1}_val_acc_{2:.2f}_val_loss_{3:.6f}'.format(nowDatetime, n_iter, accr_valid[-1], loss_valid[-1])
            saver.save(sess, './model/' + model_name)
        if n_iter == 30000:
            break
#         if n_iter > 5000:
#             if np.max(accr_train) < 0.9:
#                 if np.mean(loss_train[-50:-30]) <= np.mean(loss_train[-30:]) :
#                     hist.early_under(n_iter)
#                     early_stopping = True
#                     break
#             if np.mean(accr_train[-50:]) >= 0.995:
#                 if (
#                     np.mean(loss_valid[-41:-21]) <= np.mean(loss_valid[-21:-1]) and
#                     loss_valid[-1] < loss_valid[-2] # np.min(loss_valid[-20:]) == loss_valid[-1]
#                     ):
#                     hist.early_over(n_iter)
#                     early_stopping = True
#                     break          
    
train_time = int((time.time() - start_time)/60)  
hist.done(n_iter, train_time, early_stopping)

hist.plot(cal_interval)   

# sess.close()
# Out:
# ==============================================================
# [Iter] || Train_accr || Valid_accr || Train_loss || Valid_loss
# ==============================================================
# W0120 14:10:37.870317 140343832446720 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# [*100] || 65.00 %    || 64.00 %    || 0.65119278 || 0.62351722
# --------------------------------------------------------------
# [*200] || 61.00 %    || 70.00 %    || 0.61580014 || 0.56788957
# --------------------------------------------------------------
# [*300] || 75.00 %    || 78.00 %    || 0.47211868 || 0.48015985
# --------------------------------------------------------------
# [*400] || 71.00 %    || 80.00 %    || 0.53869885 || 0.48251811
# --------------------------------------------------------------
# [*500] || 80.00 %    || 77.00 %    || 0.42572895 || 0.46207398
# --------------------------------------------------------------
# [*600] || 90.00 %    || 84.00 %    || 0.28972018 || 0.35571358
# --------------------------------------------------------------
# [*700] || 86.00 %    || 91.00 %    || 0.28318918 || 0.23736008
# --------------------------------------------------------------
# [*800] || 95.00 %    || 92.00 %    || 0.13309029 || 0.23792081
# --------------------------------------------------------------
# [*900] || 95.00 %    || 95.00 %    || 0.11502413 || 0.18776982
# --------------------------------------------------------------
# [1000] || 96.00 %    || 95.00 %    || 0.12727983 || 0.19473156
# --------------------------------------------------------------
# [1100] || 97.00 %    || 93.00 %    || 0.10687066 || 0.17134586
# --------------------------------------------------------------
# [1200] || 97.00 %    || 94.00 %    || 0.11077721 || 0.14774090
# --------------------------------------------------------------
# [1300] || 96.00 %    || 95.00 %    || 0.12596275 || 0.10348929
# --------------------------------------------------------------
# [1400] || 99.00 %    || 96.00 %    || 0.05681597 || 0.13444619
# --------------------------------------------------------------
# [1500] || 97.00 %    || 95.00 %    || 0.11252312 || 0.16708682
# --------------------------------------------------------------
# [1600] || 93.00 %    || 100.00 %    || 0.16589405 || 0.04450723
# --------------------------------------------------------------
# [1700] || 99.00 %    || 96.00 %    || 0.10791846 || 0.10292271
# --------------------------------------------------------------
# [1800] || 99.00 %    || 97.00 %    || 0.05143686 || 0.06970702
# --------------------------------------------------------------
# [1900] || 96.00 %    || 98.00 %    || 0.09522644 || 0.10041829
# --------------------------------------------------------------
# [2000] || 97.00 %    || 92.00 %    || 0.08755970 || 0.24009411
# --------------------------------------------------------------
# [2100] || 97.00 %    || 95.00 %    || 0.09815416 || 0.13146184
# --------------------------------------------------------------
# [2200] || 99.00 %    || 97.00 %    || 0.03968929 || 0.11599149
# --------------------------------------------------------------
# [2300] || 94.00 %    || 98.00 %    || 0.13049945 || 0.04440768
# --------------------------------------------------------------
# [2400] || 95.00 %    || 94.00 %    || 0.08680277 || 0.12752923
# --------------------------------------------------------------
# [2500] || 96.00 %    || 93.00 %    || 0.11077861 || 0.20483360
# --------------------------------------------------------------
# [2600] || 95.00 %    || 94.00 %    || 0.16648392 || 0.13553436
# --------------------------------------------------------------
# [2700] || 95.00 %    || 98.00 %    || 0.10403987 || 0.03924726
# --------------------------------------------------------------
# [2800] || 97.00 %    || 96.00 %    || 0.07429408 || 0.08235694
# --------------------------------------------------------------
# [2900] || 98.00 %    || 95.00 %    || 0.06289403 || 0.06394907
# --------------------------------------------------------------
# [3000] || 97.00 %    || 95.00 %    || 0.04779011 || 0.14436251
# --------------------------------------------------------------
# [3100] || 98.00 %    || 96.00 %    || 0.05231682 || 0.07170302
# --------------------------------------------------------------
# [3200] || 99.00 %    || 96.00 %    || 0.02008594 || 0.13475771
# --------------------------------------------------------------
# [3300] || 97.00 %    || 98.00 %    || 0.08082002 || 0.03120843
# --------------------------------------------------------------
# [3400] || 99.00 %    || 98.00 %    || 0.05686704 || 0.05743071
# --------------------------------------------------------------
# [3500] || 99.00 %    || 96.00 %    || 0.03932897 || 0.12468784
# --------------------------------------------------------------
# [3600] || 98.00 %    || 97.00 %    || 0.04390683 || 0.05990697
# --------------------------------------------------------------
# [3700] || 99.00 %    || 98.00 %    || 0.04076239 || 0.04587918
# --------------------------------------------------------------
# [3800] || 100.00 %    || 98.00 %    || 0.01287200 || 0.05915859
# --------------------------------------------------------------
# [3900] || 99.00 %    || 98.00 %    || 0.03810707 || 0.04783250
# --------------------------------------------------------------
# [4000] || 96.00 %    || 99.00 %    || 0.08888521 || 0.03199797
# --------------------------------------------------------------
# [4100] || 99.00 %    || 98.00 %    || 0.03019047 || 0.07485699
# --------------------------------------------------------------
# [4200] || 100.00 %    || 98.00 %    || 0.01368378 || 0.05669785
# --------------------------------------------------------------
# [4300] || 99.00 %    || 98.00 %    || 0.02514024 || 0.07635242
# --------------------------------------------------------------
# [4400] || 98.00 %    || 98.00 %    || 0.03894205 || 0.04420223
# --------------------------------------------------------------
# [4500] || 99.00 %    || 96.00 %    || 0.03423581 || 0.08118250
# --------------------------------------------------------------
# [4600] || 98.00 %    || 97.00 %    || 0.06728362 || 0.05179831
# --------------------------------------------------------------
# [4700] || 97.00 %    || 96.00 %    || 0.08913125 || 0.10472085
# --------------------------------------------------------------
# [4800] || 98.00 %    || 99.00 %    || 0.09119906 || 0.02871012
# --------------------------------------------------------------
# [4900] || 95.00 %    || 96.00 %    || 0.08919287 || 0.10292390
# --------------------------------------------------------------
# [5000] || 98.00 %    || 97.00 %    || 0.05847924 || 0.06998213
# --------------------------------------------------------------
# [5100] || 98.00 %    || 97.00 %    || 0.11583904 || 0.05213729
# --------------------------------------------------------------
# [5200] || 98.00 %    || 96.00 %    || 0.03403192 || 0.12058602
# --------------------------------------------------------------
# [5300] || 97.00 %    || 96.00 %    || 0.05187982 || 0.21469192
# --------------------------------------------------------------
# [5400] || 99.00 %    || 99.00 %    || 0.01431186 || 0.04276428
# --------------------------------------------------------------
# [5500] || 99.00 %    || 98.00 %    || 0.03638149 || 0.05633921
# --------------------------------------------------------------
# [5600] || 97.00 %    || 94.00 %    || 0.05249211 || 0.08136035
# --------------------------------------------------------------
# [5700] || 99.00 %    || 95.00 %    || 0.03244555 || 0.13721445
# --------------------------------------------------------------
# [5800] || 99.00 %    || 100.00 %    || 0.07823186 || 0.02896407
# --------------------------------------------------------------
# [5900] || 100.00 %    || 98.00 %    || 0.01888854 || 0.06666670
# --------------------------------------------------------------
# [6000] || 98.00 %    || 96.00 %    || 0.03948395 || 0.07965009
# --------------------------------------------------------------
# [6100] || 99.00 %    || 99.00 %    || 0.06452779 || 0.03424145
# --------------------------------------------------------------
# [6200] || 99.00 %    || 97.00 %    || 0.03046878 || 0.06751211
# --------------------------------------------------------------
# [6300] || 97.00 %    || 99.00 %    || 0.05291530 || 0.02595758
# --------------------------------------------------------------
# [6400] || 100.00 %    || 98.00 %    || 0.01249241 || 0.08628781
# --------------------------------------------------------------
# [6500] || 98.00 %    || 99.00 %    || 0.04944716 || 0.02476368
# --------------------------------------------------------------
# [6600] || 100.00 %    || 99.00 %    || 0.01309547 || 0.01981736
# --------------------------------------------------------------
# [6700] || 100.00 %    || 100.00 %    || 0.01403342 || 0.01555205
# --------------------------------------------------------------
# [6800] || 95.00 %    || 92.00 %    || 0.09720665 || 0.24341038
# --------------------------------------------------------------
# [6900] || 100.00 %    || 97.00 %    || 0.00515455 || 0.04889723
# --------------------------------------------------------------
# [7000] || 99.00 %    || 98.00 %    || 0.02248428 || 0.04244365
# --------------------------------------------------------------
# [7100] || 99.00 %    || 96.00 %    || 0.03977795 || 0.10542881
# --------------------------------------------------------------
# [7200] || 99.00 %    || 96.00 %    || 0.03241714 || 0.22436476
# --------------------------------------------------------------
# [7300] || 100.00 %    || 100.00 %    || 0.00811172 || 0.01810335
# --------------------------------------------------------------
# [7400] || 99.00 %    || 97.00 %    || 0.03173964 || 0.03478067
# --------------------------------------------------------------
# [7500] || 99.00 %    || 97.00 %    || 0.01905634 || 0.09216054
# --------------------------------------------------------------
# [7600] || 99.00 %    || 100.00 %    || 0.01924677 || 0.01028984
# --------------------------------------------------------------
# [7700] || 100.00 %    || 98.00 %    || 0.00955621 || 0.06923554
# --------------------------------------------------------------
# [7800] || 100.00 %    || 98.00 %    || 0.01427460 || 0.03094983
# --------------------------------------------------------------
# [7900] || 100.00 %    || 99.00 %    || 0.00817934 || 0.01222259
# --------------------------------------------------------------
# [8000] || 100.00 %    || 99.00 %    || 0.00655780 || 0.03875557
# --------------------------------------------------------------
# [8100] || 100.00 %    || 99.00 %    || 0.01905814 || 0.02255813
# --------------------------------------------------------------
# [8200] || 100.00 %    || 99.00 %    || 0.02338474 || 0.06488696
# --------------------------------------------------------------
# [8300] || 100.00 %    || 98.00 %    || 0.01853252 || 0.03772104
# --------------------------------------------------------------
# [8400] || 100.00 %    || 99.00 %    || 0.00601083 || 0.02426984
# --------------------------------------------------------------
# [8500] || 100.00 %    || 100.00 %    || 0.00905886 || 0.00929803
# --------------------------------------------------------------
# [8600] || 100.00 %    || 98.00 %    || 0.01085923 || 0.03355619
# --------------------------------------------------------------
# [8700] || 99.00 %    || 98.00 %    || 0.01665765 || 0.07242879
# --------------------------------------------------------------
# [8800] || 100.00 %    || 100.00 %    || 0.01803458 || 0.00244892
# --------------------------------------------------------------
# [8900] || 100.00 %    || 98.00 %    || 0.00718738 || 0.04781643
# --------------------------------------------------------------
# [9000] || 100.00 %    || 97.00 %    || 0.00999336 || 0.07773384
# --------------------------------------------------------------
# [9100] || 99.00 %    || 97.00 %    || 0.03982464 || 0.04554737
# --------------------------------------------------------------
# [9200] || 100.00 %    || 99.00 %    || 0.00935361 || 0.01951751
# --------------------------------------------------------------
# [9300] || 100.00 %    || 98.00 %    || 0.00338957 || 0.02924745
# --------------------------------------------------------------
# [9400] || 97.00 %    || 98.00 %    || 0.04701801 || 0.03343444
# --------------------------------------------------------------
# [9500] || 100.00 %    || 98.00 %    || 0.00775277 || 0.14867546
# --------------------------------------------------------------
# [9600] || 100.00 %    || 98.00 %    || 0.00600370 || 0.05108188
# --------------------------------------------------------------
# [9700] || 97.00 %    || 96.00 %    || 0.04882164 || 0.13184021
# --------------------------------------------------------------
# [9800] || 100.00 %    || 98.00 %    || 0.00334458 || 0.03968591
# --------------------------------------------------------------
# [9900] || 98.00 %    || 96.00 %    || 0.04740056 || 0.14169408
# --------------------------------------------------------------
# [10000] || 100.00 %    || 98.00 %    || 0.00327954 || 0.06078021
# --------------------------------------------------------------
# [10100] || 100.00 %    || 99.00 %    || 0.00544241 || 0.01961114
# --------------------------------------------------------------
# [10200] || 100.00 %    || 100.00 %    || 0.00081589 || 0.01329763
# --------------------------------------------------------------
# [10300] || 99.00 %    || 100.00 %    || 0.04726936 || 0.01579823
# --------------------------------------------------------------
# [10400] || 100.00 %    || 98.00 %    || 0.00678402 || 0.05313531
# --------------------------------------------------------------
# [10500] || 100.00 %    || 99.00 %    || 0.00219251 || 0.02704320
# --------------------------------------------------------------
# [10600] || 100.00 %    || 98.00 %    || 0.01024015 || 0.03995176
# --------------------------------------------------------------
# [10700] || 99.00 %    || 99.00 %    || 0.04541134 || 0.02191771
# --------------------------------------------------------------
# [10800] || 98.00 %    || 100.00 %    || 0.02941153 || 0.00247085
# --------------------------------------------------------------
# [10900] || 100.00 %    || 100.00 %    || 0.00246596 || 0.00481282
# --------------------------------------------------------------
# [11000] || 97.00 %    || 98.00 %    || 0.06713183 || 0.10610169
# --------------------------------------------------------------
# [11100] || 100.00 %    || 99.00 %    || 0.01488401 || 0.02468877
# --------------------------------------------------------------
# [11200] || 100.00 %    || 100.00 %    || 0.00937578 || 0.00497553
# --------------------------------------------------------------
# [11300] || 100.00 %    || 99.00 %    || 0.00224210 || 0.01295976
# --------------------------------------------------------------
# [11400] || 100.00 %    || 100.00 %    || 0.00449544 || 0.01120373
# --------------------------------------------------------------
# [11500] || 100.00 %    || 97.00 %    || 0.00220156 || 0.06022947
# --------------------------------------------------------------
# [11600] || 100.00 %    || 98.00 %    || 0.00045571 || 0.05212636
# --------------------------------------------------------------
# [11700] || 99.00 %    || 100.00 %    || 0.01239807 || 0.01283453
# --------------------------------------------------------------
# [11800] || 100.00 %    || 99.00 %    || 0.00840333 || 0.09459671
# --------------------------------------------------------------
# [11900] || 100.00 %    || 99.00 %    || 0.00051593 || 0.01133874
# --------------------------------------------------------------
# [12000] || 100.00 %    || 98.00 %    || 0.01188475 || 0.03321743
# --------------------------------------------------------------
# [12100] || 98.00 %    || 100.00 %    || 0.07040875 || 0.00445689
# --------------------------------------------------------------
# [12200] || 99.00 %    || 99.00 %    || 0.01871569 || 0.01426734
# --------------------------------------------------------------
# [12300] || 100.00 %    || 100.00 %    || 0.00241963 || 0.01101358
# --------------------------------------------------------------
# [12400] || 100.00 %    || 96.00 %    || 0.00377729 || 0.12275109
# --------------------------------------------------------------
# [12500] || 100.00 %    || 99.00 %    || 0.00139214 || 0.01545806
# --------------------------------------------------------------
# [12600] || 100.00 %    || 98.00 %    || 0.00096539 || 0.05398615
# --------------------------------------------------------------
# [12700] || 100.00 %    || 99.00 %    || 0.00344362 || 0.03542569
# --------------------------------------------------------------
# [12800] || 100.00 %    || 100.00 %    || 0.00177231 || 0.00282257
# --------------------------------------------------------------
# [12900] || 100.00 %    || 100.00 %    || 0.00445965 || 0.00050495
# --------------------------------------------------------------
# [13000] || 100.00 %    || 98.00 %    || 0.00168581 || 0.02580287
# --------------------------------------------------------------
# [13100] || 100.00 %    || 99.00 %    || 0.00422471 || 0.04279089
# --------------------------------------------------------------
# [13200] || 99.00 %    || 99.00 %    || 0.01817077 || 0.01210420
# --------------------------------------------------------------
# [13300] || 100.00 %    || 97.00 %    || 0.00246531 || 0.05797002
# --------------------------------------------------------------
# [13400] || 100.00 %    || 100.00 %    || 0.00310769 || 0.00196622
# --------------------------------------------------------------
# [13500] || 100.00 %    || 99.00 %    || 0.01147676 || 0.01739285
# --------------------------------------------------------------
# [13600] || 100.00 %    || 100.00 %    || 0.00265346 || 0.00131680
# --------------------------------------------------------------
# [13700] || 100.00 %    || 99.00 %    || 0.00525311 || 0.05550893
# --------------------------------------------------------------
# [13800] || 100.00 %    || 98.00 %    || 0.00082259 || 0.03411173
# --------------------------------------------------------------
# [13900] || 100.00 %    || 97.00 %    || 0.00920987 || 0.09487625
# --------------------------------------------------------------
# [14000] || 100.00 %    || 98.00 %    || 0.00626286 || 0.10722618
# --------------------------------------------------------------
# [14100] || 100.00 %    || 99.00 %    || 0.00822427 || 0.03392272
# --------------------------------------------------------------
# [14200] || 100.00 %    || 99.00 %    || 0.00165005 || 0.01427689
# --------------------------------------------------------------
# [14300] || 100.00 %    || 98.00 %    || 0.00086574 || 0.03105852
# --------------------------------------------------------------
# [14400] || 100.00 %    || 99.00 %    || 0.00451138 || 0.02071259
# --------------------------------------------------------------
# [14500] || 100.00 %    || 100.00 %    || 0.00275181 || 0.00489926
# --------------------------------------------------------------
# [14600] || 100.00 %    || 100.00 %    || 0.00663773 || 0.00176786
# --------------------------------------------------------------
# [14700] || 100.00 %    || 100.00 %    || 0.00350815 || 0.00953158
# --------------------------------------------------------------
# [14800] || 100.00 %    || 96.00 %    || 0.00632228 || 0.08696714
# --------------------------------------------------------------
# [14900] || 100.00 %    || 99.00 %    || 0.00201884 || 0.03482397
# --------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-152f07ead34d> in <module>
#      17 while True:
#      18     neg_train_x, neg_train_y = load_random_minibatch(neg_train_path, cls = 0, batch_size = n_batch)
# ---> 19     a_train_x, a_train_y = load_random_minibatch(a_train_path, cls = 1, batch_size = n_batch)
#      20     train_x = np.vstack([neg_train_x, a_train_x])
#      21     train_y = np.vstack([neg_train_y, a_train_y])
#
# /mnt/disk1/project/SMhospital/capsule/ce_packages/ce_utils.py in load_random_minibatch(pathlist, cls, n_cls, batch_size, image_ch)
#     195     batch = []
#     196     for i in batch_dir:
# --> 197         temp = cv2.imread(i)
#     198         if image_ch == 'bgr':
#     199             pass
#
# KeyboardInterrupt:

# %%
hist.plot(cal_interval)

# %%
a_crop_path = []

for p in a_valid_path:
    name = os.path.basename(p)
    if (name.split('c_')[-1])[:-4] == '-_-_-':
        a_crop_path.append(p)
        
a_crop_path = np.asarray(a_crop_path)

# %%
len(a_crop_path)
# Out:
# 109

# %%
accr_list = []

for i in range(30):
    a_valid_x, a_valid_y = load_random_minibatch(a_crop_path, cls = 1, batch_size = n_batch)
    p = sess.run(score, feed_dict = {'img:0': a_valid_x, 'is_training:0' :0})

    pred = np.argmax(p, axis = 1)
    true = np.argmax(a_valid_y, axis =1)
    
    accr_list.append(np.mean(np.equal(pred, true)))

# %%
np.mean(accr_list)
# Out:
# 1.0

# %%
hist.table()

start_time = time.time()

while True:
    neg_train_x, neg_train_y = load_random_minibatch(neg_train_path, cls = 0, batch_size = n_batch)
    a_train_x, a_train_y = load_random_minibatch(a_train_path, cls = 1, batch_size = n_batch)
    train_x = np.vstack([neg_train_x, a_train_x])
    train_y = np.vstack([neg_train_y, a_train_y])
    train_x, train_y = shuffle(train_x, train_y)
    
    sess.run(optm, feed_dict = {'img:0': train_x, 'label:0': train_y, 'is_training:0' :1, LR: D_lr[n_iter]})
    n_iter += 1
    
    if n_iter % cal_interval == 0:
        c, p = sess.run([loss, score], feed_dict = {'img:0': train_x, 'label:0': train_y, 'is_training:0' :0})

        p = np.argmax(p, axis = 1)
        l = np.argmax(train_y, axis = 1)
        a = np.mean(np.equal(p, l))
        
        neg_valid_x, neg_valid_y = load_random_minibatch(neg_valid_path, cls = 0, batch_size = n_batch)
        a_valid_x, a_valid_y = load_random_minibatch(a_valid_path, cls = 1, batch_size = n_batch)
        valid_x = np.vstack([neg_valid_x, a_valid_x])
        valid_y = np.vstack([neg_valid_y, a_valid_y])
        
        c_valid, p_valid = sess.run([loss, score], feed_dict = {'img:0': valid_x, 'label:0': valid_y, 'is_training:0' :0})

        p_valid = np.argmax(p_valid, axis = 1)
        l_valid = np.argmax(valid_y, axis = 1)
        a_valid = np.mean(np.equal(p_valid, l_valid))

        accr_valid.append(a_valid)
        loss_valid.append(c_valid)
        accr_train.append(a)
        loss_train.append(c)

        if n_iter % prt_interval == 0:
            hist.prt_evl(n_iter)

        if loss_valid[-1] == np.min(loss_valid):
            now = datetime.datetime.now()
            nowDatetime = now.strftime('%y%m%d%H%M')
            model_name = 'X160_frb_NH_{0}_{1}_val_acc_{2:.2f}_val_loss_{3:.6f}'.format(nowDatetime, n_iter, accr_valid[-1], loss_valid[-1])
            saver.save(sess, './model/' + model_name)
        if n_iter == 30000:
            break
#         if n_iter > 5000:
#             if np.max(accr_train) < 0.9:
#                 if np.mean(loss_train[-50:-30]) <= np.mean(loss_train[-30:]) :
#                     hist.early_under(n_iter)
#                     early_stopping = True
#                     break
#             if np.mean(accr_train[-50:]) >= 0.995:
#                 if (
#                     np.mean(loss_valid[-41:-21]) <= np.mean(loss_valid[-21:-1]) and
#                     loss_valid[-1] < loss_valid[-2] # np.min(loss_valid[-20:]) == loss_valid[-1]
#                     ):
#                     hist.early_over(n_iter)
#                     early_stopping = True
#                     break          
    
train_time = int((time.time() - start_time)/60)  
hist.done(n_iter, train_time, early_stopping)

hist.plot(cal_interval)   

# sess.close()
# Out:
# ==============================================================
# [Iter] || Train_accr || Valid_accr || Train_loss || Valid_loss
# ==============================================================
# [15000] || 99.00 %    || 99.00 %    || 0.01706284 || 0.02116933
# --------------------------------------------------------------
# [15100] || 100.00 %    || 98.00 %    || 0.00589199 || 0.11313663
# --------------------------------------------------------------
# [15200] || 100.00 %    || 100.00 %    || 0.00814475 || 0.00138132
# --------------------------------------------------------------
# [15300] || 100.00 %    || 100.00 %    || 0.00254459 || 0.00173423
# --------------------------------------------------------------
# [15400] || 100.00 %    || 99.00 %    || 0.00201295 || 0.03267661
# --------------------------------------------------------------
# [15500] || 100.00 %    || 100.00 %    || 0.00202079 || 0.00236264
# --------------------------------------------------------------
# [15600] || 100.00 %    || 100.00 %    || 0.00062687 || 0.00030841
# --------------------------------------------------------------
# [15700] || 100.00 %    || 98.00 %    || 0.00376191 || 0.09919501
# --------------------------------------------------------------
# [15800] || 100.00 %    || 97.00 %    || 0.00486714 || 0.08139133
# --------------------------------------------------------------
# [15900] || 100.00 %    || 100.00 %    || 0.01133522 || 0.01222496
# --------------------------------------------------------------
# [16000] || 100.00 %    || 100.00 %    || 0.00945294 || 0.00252045
# --------------------------------------------------------------
# [16100] || 100.00 %    || 100.00 %    || 0.00272375 || 0.01197726
# --------------------------------------------------------------
# [16200] || 100.00 %    || 98.00 %    || 0.00064020 || 0.05916752
# --------------------------------------------------------------
# [16300] || 100.00 %    || 98.00 %    || 0.00069502 || 0.04188246
# --------------------------------------------------------------
# [16400] || 100.00 %    || 98.00 %    || 0.00118114 || 0.01790947
# --------------------------------------------------------------
# [16500] || 100.00 %    || 96.00 %    || 0.00363727 || 0.13283181
# --------------------------------------------------------------
# [16600] || 100.00 %    || 99.00 %    || 0.00122768 || 0.02605977
# --------------------------------------------------------------
# [16700] || 100.00 %    || 100.00 %    || 0.00017617 || 0.00052862
# --------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-77704f8ad06d> in <module>
#      10     train_x, train_y = shuffle(train_x, train_y)
#      11
# ---> 12     sess.run(optm, feed_dict = {'img:0': train_x, 'label:0': train_y, 'is_training:0' :1, LR: D_lr[n_iter]})
#      13     n_iter += 1
#      14
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
