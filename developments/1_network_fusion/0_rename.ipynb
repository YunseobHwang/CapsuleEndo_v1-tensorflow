# %%
import sys 
import os
from os import rename, listdir

# %% [markdown]
# # jupyter

# %%
files = listdir('.')

# %%
files
# Out:
# ['.ipynb_checkpoints',
#  '__pycache__',
#  'old',
#  '1_training - CORE Binary model.ipynb',
#  '2_evaluation - CORE models 5000 7000 for COREset.ipynb',
#  '2_evaluation - CORE models for ENTIREset2.ipynb',
#  '2_evaluation - ENTIRE models for ENTIREset.ipynb',
#  '1_training - ENTIRE2 N1D9 model (training batch N_D = 1_9).ipynb',
#  '1_training - ENTIRE N3H7 model.ipynb',
#  '2_evaluation - ENTIRE models (N_A=3_7) for ENTIREset.ipynb',
#  '1_training - CORE NH 5000 model (bgr).ipynb',
#  'model',
#  '2_evaluation - ENTIRE2 models (N_A=1_9) for ENTIRE2set-Copy1.ipynb',
#  '1_training - CORE Binary 5000 model (bgr).ipynb',
#  '2_evaluation - ENTIRE B model BN for ENTIREset.ipynb',
#  '1_training - CORE NH model.ipynb',
#  '2_evaluation - CORE models for ENTIREset.ipynb',
#  '1_training - ENTIRE2 NH model (bgr).ipynb',
#  '2_evaluation - CORE models for COREset.ipynb',
#  '2_evaluation - ENTIRE2 models for ENTIRE2set.ipynb',
# ...

# %%
# check

for filename in files:
    if filename.endswith("ipynb"):
        new_filename = filename.replace('COREset', 'sm_core testset')
        new_filename = new_filename.replace('ENTIREset', 'sm testset')
        new_filename = new_filename.replace('ENTIREset2', 'sm_v2 testset')
        new_filename = new_filename.replace('ENTIRE2', 'sm_v2') 
        new_filename = new_filename.replace('ENTIRE', 'sm') 
        new_filename = new_filename.replace('CORE', 'sm_core') 
#         os.rename(filename, new_filename)
        print(filename, '\n', '-->', new_filename)
        print("")
# Out:
# 1_training - CORE Binary model.ipynb
#  --> 1_training - sm_core Binary model.ipynb
#
# 2_evaluation - CORE models 5000 7000 for COREset.ipynb
#  --> 2_evaluation - sm_core models 5000 7000 for sm_core testset.ipynb
#
# 2_evaluation - CORE models for ENTIREset2.ipynb
#  --> 2_evaluation - sm_core models for sm testset2.ipynb
#
# 2_evaluation - ENTIRE models for ENTIREset.ipynb
#  --> 2_evaluation - sm models for sm testset.ipynb
#
# 1_training - ENTIRE2 N1D9 model (training batch N_D = 1_9).ipynb
#  --> 1_training - sm_v2 N1D9 model (training batch N_D = 1_9).ipynb
#
# 1_training - ENTIRE N3H7 model.ipynb
#  --> 1_training - sm N3H7 model.ipynb
#
# 2_evaluation - ENTIRE models (N_A=3_7) for ENTIREset.ipynb
#  --> 2_evaluation - sm models (N_A=3_7) for sm testset.ipynb
#
# 1_training - CORE NH 5000 model (bgr).ipynb
#  --> 1_training - sm_core NH 5000 model (bgr).ipynb
#
# 2_evaluation - ENTIRE2 models (N_A=1_9) for ENTIRE2set-Copy1.ipynb
# ...

# %%
for filename in files:
    if filename.endswith("ipynb"):
        new_filename = filename.replace('COREset', 'sm_core testset')
        new_filename = new_filename.replace('ENTIREset', 'sm testset')
        new_filename = new_filename.replace('ENTIREset2', 'sm_v2 testset')
        new_filename = new_filename.replace('ENTIRE2', 'sm_v2') 
        new_filename = new_filename.replace('ENTIRE', 'sm') 
        new_filename = new_filename.replace('CORE', 'sm_core') 
        
        print(filename, '\n', '-->', new_filename)
        os.rename(filename, new_filename)
        print("  --> renaming is done")
        print("")
# Out:
# 1_training - CORE Binary model.ipynb
#  --> 1_training - sm_core Binary model.ipynb
#   --> renaming is done
#
# 2_evaluation - CORE models 5000 7000 for COREset.ipynb
#  --> 2_evaluation - sm_core models 5000 7000 for sm_core testset.ipynb
#   --> renaming is done
#
# 2_evaluation - CORE models for ENTIREset2.ipynb
#  --> 2_evaluation - sm_core models for sm testset2.ipynb
#   --> renaming is done
#
# 2_evaluation - ENTIRE models for ENTIREset.ipynb
#  --> 2_evaluation - sm models for sm testset.ipynb
#   --> renaming is done
#
# 1_training - ENTIRE2 N1D9 model (training batch N_D = 1_9).ipynb
#  --> 1_training - sm_v2 N1D9 model (training batch N_D = 1_9).ipynb
#   --> renaming is done
#
# 1_training - ENTIRE N3H7 model.ipynb
#  --> 1_training - sm N3H7 model.ipynb
#   --> renaming is done
#
# 2_evaluation - ENTIRE models (N_A=3_7) for ENTIREset.ipynb
#  --> 2_evaluation - sm models (N_A=3_7) for sm testset.ipynb
#   --> renaming is done
#
# ...

# %%
files = sorted(listdir('.'))

# %%
files
# Out:
# ['.ipynb_checkpoints',
#  '0_data size .ipynb',
#  '0_remove the overlapped negative images.ipynb',
#  '0_rename filename.ipynb',
#  '1_training - sm Binary model  - BN.ipynb',
#  '1_training - sm Binary model .ipynb',
#  '1_training - sm N3D7 model.ipynb',
#  '1_training - sm N3H7 model.ipynb',
#  '1_training - sm ND model  ES v2.ipynb',
#  '1_training - sm ND model (bgr) ES v2.ipynb',
#  '1_training - sm_core Binary 5000 model .ipynb',
#  '1_training - sm_core ND 7000 model .ipynb',
#  '1_training - sm_core NH 5000 model .ipynb',
#  '1_training - sm_core rgb Binary model.ipynb',
#  '1_training - sm_core rgb ND model.ipynb',
#  '1_training - sm_core rgb NH model.ipynb',
#  '1_training - sm_v2 Binary model .ipynb',
#  '1_training - sm_v2 N1D9 model (training batch N_D = 1_9).ipynb',
#  '1_training - sm_v2 N1H9 model (training batch N_H = 1_9).ipynb',
#  '1_training - sm_v2 ND model .ipynb',
#  '1_training - sm_v2 NH model .ipynb',
# ...

# %%
for filename in files:
    if filename.endswith("ipynb"):
        new_filename = filename.replace('sm_v2set', 'sm_v2 testset')
        new_filename = new_filename.replace('(bgr)', '')
        
        print(filename, '\n', '-->', new_filename)
        os.rename(filename, new_filename)
        print("  --> renaming is done")
        print("")
# Out:
# 0_data size .ipynb
#  --> 0_data size .ipynb
#   --> renaming is done
#
# 0_remove the overlapped negative images.ipynb
#  --> 0_remove the overlapped negative images.ipynb
#   --> renaming is done
#
# 0_rename filename.ipynb
#  --> 0_rename filename.ipynb
#   --> renaming is done
#
# 1_training - ENTIRE Binary model (bgr) - BN.ipynb
#  --> 1_training - ENTIRE Binary model  - BN.ipynb
#   --> renaming is done
#
# 1_training - ENTIRE ND model (bgr) ES v2.ipynb
#  --> 1_training - ENTIRE ND model  ES v2.ipynb
#   --> renaming is done
#
# 1_training - ENTIRE NH model (bgr) ES v2.ipynb
#  --> 1_training - ENTIRE NH model  ES v2.ipynb
#   --> renaming is done
#
# 1_training - sm Binary model (bgr) - BN.ipynb
#  --> 1_training - sm Binary model  - BN.ipynb
#   --> renaming is done
#
# 1_training - sm Binary model (bgr).ipynb
#  --> 1_training - sm Binary model .ipynb
#   --> renaming is done
#
# 1_training - sm N3D7 model.ipynb
#  --> 1_training - sm N3D7 model.ipynb
# ...

# %%
for filename in files:
    if filename.endswith("ipynb"):
        new_filename = filename.replace('sm_core', 'CORE')
        new_filename = new_filename.replace('sm_v2', 'ENTIRE2')
        new_filename = new_filename.replace('sm', 'ENTIRE')

        print(filename, '\n', '-->', new_filename)
        os.rename(filename, new_filename)
        print("  --> renaming is done")
        print("")
# Out:
# 0_data size .ipynb
#  --> 0_data size .ipynb
#   --> renaming is done
#
# 0_remove the overlapped negative images.ipynb
#  --> 0_remove the overlapped negative images.ipynb
#   --> renaming is done
#
# 0_rename filename.ipynb
#  --> 0_rename filename.ipynb
#   --> renaming is done
#
# 1_training - sm Binary model  - BN.ipynb
#  --> 1_training - ENTIRE Binary model  - BN.ipynb
#   --> renaming is done
#
# 1_training - sm Binary model .ipynb
#  --> 1_training - ENTIRE Binary model .ipynb
#   --> renaming is done
#
# 1_training - sm N3D7 model.ipynb
#  --> 1_training - ENTIRE N3D7 model.ipynb
#   --> renaming is done
#
# 1_training - sm N3H7 model.ipynb
#  --> 1_training - ENTIRE N3H7 model.ipynb
#   --> renaming is done
#
# 1_training - sm ND model  ES v2.ipynb
#  --> 1_training - ENTIRE ND model  ES v2.ipynb
#   --> renaming is done
#
# 1_training - sm ND model (bgr) ES v2.ipynb
#  --> 1_training - ENTIRE ND model (bgr) ES v2.ipynb
#   --> renaming is done
#
# ...

# %% [markdown]
# # model name

# %% [markdown]
# ## model_datatype (ND_sm, NH_sm_v2, sm_ES2 ...

# %%
files = listdir('./model')

# %%
files
# Out:
# ['ND_1908302155_7140_val_acc_1.00_val_loss_0.002939.data-00000-of-00001',
#  'ND_1908302155_7140_val_acc_1.00_val_loss_0.002939.index',
#  'ND_1908302155_7140_val_acc_1.00_val_loss_0.002939.meta',
#  'NHD_1908242109_8570_val_acc_1.00_val_loss_0.011026.data-00000-of-00001',
#  'NHD_1908242109_8570_val_acc_1.00_val_loss_0.011026.index',
#  'NHD_1908242109_8570_val_acc_1.00_val_loss_0.011026.meta',
#  'NH_1908312018_5750_val_acc_1.00_val_loss_0.001598.data-00000-of-00001',
#  'NH_1908312018_5750_val_acc_1.00_val_loss_0.001598.index',
#  'NH_1908312018_5750_val_acc_1.00_val_loss_0.001598.meta',
#  'checkpoint',
#  '.ipynb_checkpoints',
#  'B_2001081734_8800_val_acc_0.97_val_loss_0.077247.meta',
#  'NH_2001060208_6000_val_acc_1.00_val_loss_0.005527.index',
#  'NH_2001081619_3800_val_acc_0.97_val_loss_0.054612.data-00000-of-00001',
#  'NH_2001060208_6000_val_acc_1.00_val_loss_0.005527.meta',
#  'NH_2001081619_3800_val_acc_0.97_val_loss_0.054612.index',
# ...

# %%
nd_list, nh_list, b_list, rest_list = [], [], [], []

for f in files:
    if 'ND' in f and 'NHD' not in f:
        nd_list.append(f)
    elif 'NH' in f and 'NHD' not in f:
        nh_list.append(f)
    elif 'B' in f or 'NHD' in f:
        b_list.append(f)
    else:
        rest_list.append(f)

# %%
nd_list
# Out:
# ['ND_1908302155_7140_val_acc_1.00_val_loss_0.002939.data-00000-of-00001',
#  'ND_1908302155_7140_val_acc_1.00_val_loss_0.002939.index',
#  'ND_1908302155_7140_val_acc_1.00_val_loss_0.002939.meta',
#  'ND_2001081615_2800_val_acc_0.96_val_loss_0.113698.data-00000-of-00001',
#  'ND_2001081650_6300_val_acc_0.98_val_loss_0.049867.meta',
#  'ND_2001081634_4700_val_acc_0.95_val_loss_0.104473.meta',
#  'ND_2001100010_10_val_acc_0.50_val_loss_0.691652.meta',
#  'ND_2001081615_2800_val_acc_0.96_val_loss_0.113698.meta',
#  'ND_2001081614_2700_val_acc_0.95_val_loss_0.130868.meta',
#  'ND_2001081615_2800_val_acc_0.96_val_loss_0.113698.index',
#  'ND_2001081650_6300_val_acc_0.98_val_loss_0.049867.data-00000-of-00001',
#  'ND_2001081639_5200_val_acc_0.97_val_loss_0.078812.meta',
#  'ND_2001081650_6300_val_acc_0.98_val_loss_0.049867.index',
#  'ND_2001081639_5200_val_acc_0.97_val_loss_0.078812.index',
#  'ND_2001100010_50_val_acc_0.48_val_loss_0.690351.meta',
# ...

# %%
nh_list
# Out:
# ['NH_1908312018_5750_val_acc_1.00_val_loss_0.001598.data-00000-of-00001',
#  'NH_1908312018_5750_val_acc_1.00_val_loss_0.001598.index',
#  'NH_1908312018_5750_val_acc_1.00_val_loss_0.001598.meta',
#  'NH_2001060208_6000_val_acc_1.00_val_loss_0.005527.index',
#  'NH_2001081619_3800_val_acc_0.97_val_loss_0.054612.data-00000-of-00001',
#  'NH_2001060208_6000_val_acc_1.00_val_loss_0.005527.meta',
#  'NH_2001081619_3800_val_acc_0.97_val_loss_0.054612.index',
#  'NH_2001060204_5320_val_acc_1.00_val_loss_0.009253.data-00000-of-00001',
#  'NH_2001060150_2870_val_acc_0.98_val_loss_0.027345.index',
#  'NH_2001081601_2100_val_acc_0.97_val_loss_0.057087.data-00000-of-00001',
#  'NH_2001081601_2100_val_acc_0.97_val_loss_0.057087.meta',
#  'NH_2001081626_4500_val_acc_0.98_val_loss_0.046558.meta',
#  'NH_2001060150_2870_val_acc_0.98_val_loss_0.027345.data-00000-of-00001',
#  'NH_2001060148_2540_val_acc_1.00_val_loss_0.034387.meta',
#  'NH_2001060148_2540_val_acc_1.00_val_loss_0.034387.index',
# ...

# %%
b_list
# Out:
# ['NHD_1908242109_8570_val_acc_1.00_val_loss_0.011026.data-00000-of-00001',
#  'NHD_1908242109_8570_val_acc_1.00_val_loss_0.011026.index',
#  'NHD_1908242109_8570_val_acc_1.00_val_loss_0.011026.meta',
#  'B_2001081734_8800_val_acc_0.97_val_loss_0.077247.meta',
#  'B_2001081801_11400_val_acc_0.98_val_loss_0.050810.meta',
#  'B_2001081821_13300_val_acc_0.98_val_loss_0.042233.index',
#  'B_2001100013_150_val_acc_0.66_val_loss_0.650705.data-00000-of-00001',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.meta',
#  'B_2001081739_9300_val_acc_0.98_val_loss_0.059156.index',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.data-00000-of-00001',
#  'B_2001081801_11400_val_acc_0.98_val_loss_0.050810.index',
#  'B_2001081734_8800_val_acc_0.97_val_loss_0.077247.data-00000-of-00001',
#  'B_2001081714_6900_val_acc_0.96_val_loss_0.094075.meta',
#  'B_2001081821_13300_val_acc_0.98_val_loss_0.042233.meta',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.index',
# ...

# %%
rest_list
# Out:
# ['checkpoint',
#  '.ipynb_checkpoints',
#  'N1H9_2001101659_3550_val_acc_0.99_val_loss_0.025578.data-00000-of-00001',
#  'N1D9_2001100204_4990_val_acc_0.99_val_loss_0.027827.meta',
#  'N1H9_2001101648_2940_val_acc_0.99_val_loss_0.031713.meta',
#  'N1D9_2001100204_4990_val_acc_0.99_val_loss_0.027827.index',
#  'N1D9_2001100202_4900_val_acc_0.99_val_loss_0.039726.meta',
#  'N1D9_2001100219_5810_val_acc_0.99_val_loss_0.022532.meta',
#  'N1D9_2001100152_4380_val_acc_0.98_val_loss_0.039794.meta',
#  'N1H9_2001101705_3820_val_acc_1.00_val_loss_0.008359.data-00000-of-00001',
#  'N1D9_2001100206_5120_val_acc_0.99_val_loss_0.026593.index',
#  'N1H9_2001101713_4250_val_acc_1.00_val_loss_0.006335.data-00000-of-00001',
#  'N1H9_2001101659_3550_val_acc_0.99_val_loss_0.025578.index',
#  'N1H9_2001101705_3820_val_acc_1.00_val_loss_0.008359.index',
#  'N1D9_2001100202_4900_val_acc_0.99_val_loss_0.039726.data-00000-of-00001',
#  'N1H9_2001101713_4250_val_acc_1.00_val_loss_0.006335.index',
# ...

# %%
sys.path
# Out:
# ['/usr/lib/python35.zip',
#  '/usr/lib/python3.5',
#  '/usr/lib/python3.5/plat-x86_64-linux-gnu',
#  '/usr/lib/python3.5/lib-dynload',
#  '',
#  '/home/project/.local/lib/python3.5/site-packages',
#  '/usr/local/lib/python3.5/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/home/project/.local/lib/python3.5/site-packages/IPython/extensions',
#  '/home/project/.ipython',
#  './model']

# %%
os.rename?

# %%
os.chdir('./model')

# %%
for filename in files:
    if 'NH_19' in filename:
        new_filename = filename.replace('NH_19', 'NH_sm_rgb_19')
        print(new_filename)
        os.rename(filename, new_filename)
    if 'ND_19' in filename:
        new_filename = filename.replace('ND_19', 'ND_sm_rgb_19')
        print(new_filename)
        os.rename(filename, new_filename)
    if 'NHD_19' in filename:
        new_filename = filename.replace('NHD_19', 'B_sm_rgb_19')
        print(new_filename)
        os.rename(filename, new_filename)
# Out:
# ND_sm_rgb_1908302155_7140_val_acc_1.00_val_loss_0.002939.data-00000-of-00001
# ND_sm_rgb_1908302155_7140_val_acc_1.00_val_loss_0.002939.index
# ND_sm_rgb_1908302155_7140_val_acc_1.00_val_loss_0.002939.meta
# B_sm_rgb_1908242109_8570_val_acc_1.00_val_loss_0.011026.data-00000-of-00001
# B_sm_rgb_1908242109_8570_val_acc_1.00_val_loss_0.011026.index
# B_sm_rgb_1908242109_8570_val_acc_1.00_val_loss_0.011026.meta
# NH_sm_rgb_1908312018_5750_val_acc_1.00_val_loss_0.001598.data-00000-of-00001
# NH_sm_rgb_1908312018_5750_val_acc_1.00_val_loss_0.001598.index
# NH_sm_rgb_1908312018_5750_val_acc_1.00_val_loss_0.001598.meta

# %%
for filename in files:
    if 'NH_core_200104' in filename:
        new_filename = filename.replace('NH_core_200104', 'NH_sm_core_rgb_200104')
        print(new_filename)
        os.rename(filename, new_filename)
    if 'ND_core_200104' in filename:
        new_filename = filename.replace('ND_core_200104', 'ND_sm_core_rgb_200104')
        print(new_filename)
        os.rename(filename, new_filename)
    if 'B_core_200104' in filename:
        new_filename = filename.replace('B_core_200104', 'B_sm_core_rgb_200104')
        print(new_filename)
        os.rename(filename, new_filename)
# Out:
# NH_sm_core_rgb_2001041909_8890_val_acc_1.00_val_loss_0.000000.meta
# NH_sm_core_rgb_2001041909_8960_val_acc_1.00_val_loss_0.000000.meta
# ND_sm_core_rgb_2001041923_8910_val_acc_1.00_val_loss_0.000802.index
# ND_sm_core_rgb_2001041925_9170_val_acc_1.00_val_loss_0.000772.index
# B_sm_core_rgb_2001041926_8400_val_acc_1.00_val_loss_0.000314.data-00000-of-00001
# NH_sm_core_rgb_2001041914_9540_val_acc_1.00_val_loss_0.000000.meta
# B_sm_core_rgb_2001041919_7670_val_acc_1.00_val_loss_0.001308.index
# NH_sm_core_rgb_2001041908_8770_val_acc_1.00_val_loss_0.000000.index
# ND_sm_core_rgb_2001041925_9170_val_acc_1.00_val_loss_0.000772.meta
# B_sm_core_rgb_2001042017_14320_val_acc_1.00_val_loss_0.000236.data-00000-of-00001
# ND_sm_core_rgb_2001042229_12730_val_acc_1.00_val_loss_0.000018.meta
# ND_sm_core_rgb_2001041923_8910_val_acc_1.00_val_loss_0.000802.meta
# NH_sm_core_rgb_2001041909_8890_val_acc_1.00_val_loss_0.000000.data-00000-of-00001
# ...

# %%
files2 = sorted(listdir('.'))

# %%
files2
# Out:
# ['.ipynb_checkpoints',
#  'B_1_2001112003_8680_val_acc_1.00_val_loss_0.002840.data-00000-of-00001',
#  'B_1_2001112003_8680_val_acc_1.00_val_loss_0.002840.index',
#  'B_1_2001112003_8680_val_acc_1.00_val_loss_0.002840.meta',
#  'B_1_2001112051_11240_val_acc_1.00_val_loss_0.002717.data-00000-of-00001',
#  'B_1_2001112051_11240_val_acc_1.00_val_loss_0.002717.index',
#  'B_1_2001112051_11240_val_acc_1.00_val_loss_0.002717.meta',
#  'B_1_2001112054_11400_val_acc_1.00_val_loss_0.002119.data-00000-of-00001',
#  'B_1_2001112054_11400_val_acc_1.00_val_loss_0.002119.index',
#  'B_1_2001112054_11400_val_acc_1.00_val_loss_0.002119.meta',
#  'B_1_2001112127_13190_val_acc_1.00_val_loss_0.001404.data-00000-of-00001',
#  'B_1_2001112127_13190_val_acc_1.00_val_loss_0.001404.index',
#  'B_1_2001112127_13190_val_acc_1.00_val_loss_0.001404.meta',
#  'B_1_2001112151_14470_val_acc_1.00_val_loss_0.000708.data-00000-of-00001',
#  'B_1_2001112151_14470_val_acc_1.00_val_loss_0.000708.index',
# ...

# %%
for filename in files2:
    if 'NH_1_20' in filename:
        new_filename = filename.replace('NH_1_20', 'NH_sm_20')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    if 'ND_1_20' in filename:
        new_filename = filename.replace('ND_1_20', 'ND_sm_20')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    if 'B_1_20' in filename:
        new_filename = filename.replace('B_1_20', 'B_sm_20')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# B_1_2001112003_8680_val_acc_1.00_val_loss_0.002840.data-00000-of-00001
#  --> B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.data-00000-of-00001
#
# B_1_2001112003_8680_val_acc_1.00_val_loss_0.002840.index
#  --> B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.index
#
# B_1_2001112003_8680_val_acc_1.00_val_loss_0.002840.meta
#  --> B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.meta
#
# B_1_2001112051_11240_val_acc_1.00_val_loss_0.002717.data-00000-of-00001
#  --> B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.data-00000-of-00001
#
# B_1_2001112051_11240_val_acc_1.00_val_loss_0.002717.index
#  --> B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.index
#
# B_1_2001112051_11240_val_acc_1.00_val_loss_0.002717.meta
#  --> B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.meta
#
# B_1_2001112054_11400_val_acc_1.00_val_loss_0.002119.data-00000-of-00001
#  --> B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.data-00000-of-00001
#
# ...

# %%
files3 = sorted(listdir('.'))

# %%
files3
# Out:
# ['.ipynb_checkpoints',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.data-00000-of-00001',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.index',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.meta',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.data-00000-of-00001',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.index',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.meta',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.data-00000-of-00001',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.index',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.meta',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.data-00000-of-00001',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.index',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.meta',
#  'B_2001060534_13690_val_acc_1.00_val_loss_0.006853.data-00000-of-00001',
#  'B_2001060534_13690_val_acc_1.00_val_loss_0.006853.index',
# ...

# %%
for filename in files3:
    if 'B_BN' in filename:
        new_filename = filename.replace('B_BN', 'B_sm_BN')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# B_BN_2001112308_100_val_acc_0.63_val_loss_0.638080.data-00000-of-00001
#  --> B_sm_BN_2001112308_100_val_acc_0.63_val_loss_0.638080.data-00000-of-00001
#
# B_BN_2001112308_100_val_acc_0.63_val_loss_0.638080.index
#  --> B_sm_BN_2001112308_100_val_acc_0.63_val_loss_0.638080.index
#
# B_BN_2001112308_100_val_acc_0.63_val_loss_0.638080.meta
#  --> B_sm_BN_2001112308_100_val_acc_0.63_val_loss_0.638080.meta
#
# B_BN_2001112308_110_val_acc_0.70_val_loss_0.571329.data-00000-of-00001
#  --> B_sm_BN_2001112308_110_val_acc_0.70_val_loss_0.571329.data-00000-of-00001
#
# B_BN_2001112308_110_val_acc_0.70_val_loss_0.571329.index
#  --> B_sm_BN_2001112308_110_val_acc_0.70_val_loss_0.571329.index
#
# B_BN_2001112308_110_val_acc_0.70_val_loss_0.571329.meta
#  --> B_sm_BN_2001112308_110_val_acc_0.70_val_loss_0.571329.meta
#
# B_BN_2001112308_80_val_acc_0.57_val_loss_0.690358.data-00000-of-00001
#  --> B_sm_BN_2001112308_80_val_acc_0.57_val_loss_0.690358.data-00000-of-00001
#
# ...

# %%
files4 = sorted(listdir('.'))

# %%
files4
# Out:
# ['.ipynb_checkpoints',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.data-00000-of-00001',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.index',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.meta',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.data-00000-of-00001',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.index',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.meta',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.data-00000-of-00001',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.index',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.meta',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.data-00000-of-00001',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.index',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.meta',
#  'B_2001060534_13690_val_acc_1.00_val_loss_0.006853.data-00000-of-00001',
#  'B_2001060534_13690_val_acc_1.00_val_loss_0.006853.index',
# ...

# %%
for filename in files4:
    if 'NH_ES2' in filename:
        new_filename = filename.replace('NH_ES2', 'NH_sm_ES2')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    if 'ND_ES2' in filename:
        new_filename = filename.replace('ND_ES2', 'ND_sm_ES2')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    if 'B_ES2' in filename:
        new_filename = filename.replace('B_ES2', 'B_sm_ES2')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# ND_ES2_2001120319_8200_mean_loss_val_0.110442.data-00000-of-00001
#  --> ND_sm_ES2_2001120319_8200_mean_loss_val_0.110442.data-00000-of-00001
#
# ND_ES2_2001120319_8200_mean_loss_val_0.110442.index
#  --> ND_sm_ES2_2001120319_8200_mean_loss_val_0.110442.index
#
# ND_ES2_2001120319_8200_mean_loss_val_0.110442.meta
#  --> ND_sm_ES2_2001120319_8200_mean_loss_val_0.110442.meta
#
# ND_ES2_2001120319_8210_mean_loss_val_0.102050.data-00000-of-00001
#  --> ND_sm_ES2_2001120319_8210_mean_loss_val_0.102050.data-00000-of-00001
#
# ND_ES2_2001120319_8210_mean_loss_val_0.102050.index
#  --> ND_sm_ES2_2001120319_8210_mean_loss_val_0.102050.index
#
# ND_ES2_2001120319_8210_mean_loss_val_0.102050.meta
#  --> ND_sm_ES2_2001120319_8210_mean_loss_val_0.102050.meta
#
# ND_ES2_2001120347_9700_mean_loss_val_0.093617.data-00000-of-00001
#  --> ND_sm_ES2_2001120347_9700_mean_loss_val_0.093617.data-00000-of-00001
#
# ND_ES2_2001120347_9700_mean_loss_val_0.093617.index
# ...

# %%
files5 = sorted(listdir('.'))

# %%
files5
# Out:
# ['.ipynb_checkpoints',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.data-00000-of-00001',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.index',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.meta',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.data-00000-of-00001',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.index',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.meta',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.data-00000-of-00001',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.index',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.meta',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.data-00000-of-00001',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.index',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.meta',
#  'B_2001060534_13690_val_acc_1.00_val_loss_0.006853.data-00000-of-00001',
#  'B_2001060534_13690_val_acc_1.00_val_loss_0.006853.index',
# ...

# %%
for filename in files5:
    if 'N1H9' in filename:
        new_filename = filename.replace('N1H9', 'N1H9_sm_v2')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    if 'N1D9' in filename:
        new_filename = filename.replace('N1D9', 'N1D9_sm_v2')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# N1D9_2001100152_4380_val_acc_0.98_val_loss_0.039794.data-00000-of-00001
#  --> N1D9_sm_v2_2001100152_4380_val_acc_0.98_val_loss_0.039794.data-00000-of-00001
#
# N1D9_2001100152_4380_val_acc_0.98_val_loss_0.039794.index
#  --> N1D9_sm_v2_2001100152_4380_val_acc_0.98_val_loss_0.039794.index
#
# N1D9_2001100152_4380_val_acc_0.98_val_loss_0.039794.meta
#  --> N1D9_sm_v2_2001100152_4380_val_acc_0.98_val_loss_0.039794.meta
#
# N1D9_2001100202_4900_val_acc_0.99_val_loss_0.039726.data-00000-of-00001
#  --> N1D9_sm_v2_2001100202_4900_val_acc_0.99_val_loss_0.039726.data-00000-of-00001
#
# N1D9_2001100202_4900_val_acc_0.99_val_loss_0.039726.index
#  --> N1D9_sm_v2_2001100202_4900_val_acc_0.99_val_loss_0.039726.index
#
# N1D9_2001100202_4900_val_acc_0.99_val_loss_0.039726.meta
#  --> N1D9_sm_v2_2001100202_4900_val_acc_0.99_val_loss_0.039726.meta
#
# N1D9_2001100204_4990_val_acc_0.99_val_loss_0.027827.data-00000-of-00001
# ...

# %%
for filename in files5:
    if 'N3H7_1' in filename:
        new_filename = filename.replace('N3H7_1', 'N3H7_sm')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    if 'N3D7_1' in filename:
        new_filename = filename.replace('N3D7_1', 'N3D7_sm')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# N3D7_1_2001112020_10030_val_acc_1.00_val_loss_0.002929.data-00000-of-00001
#  --> N3D7_sm_2001112020_10030_val_acc_1.00_val_loss_0.002929.data-00000-of-00001
#
# N3D7_1_2001112020_10030_val_acc_1.00_val_loss_0.002929.index
#  --> N3D7_sm_2001112020_10030_val_acc_1.00_val_loss_0.002929.index
#
# N3D7_1_2001112020_10030_val_acc_1.00_val_loss_0.002929.meta
#  --> N3D7_sm_2001112020_10030_val_acc_1.00_val_loss_0.002929.meta
#
# N3D7_1_2001112050_11750_val_acc_1.00_val_loss_0.002261.data-00000-of-00001
#  --> N3D7_sm_2001112050_11750_val_acc_1.00_val_loss_0.002261.data-00000-of-00001
#
# N3D7_1_2001112050_11750_val_acc_1.00_val_loss_0.002261.index
#  --> N3D7_sm_2001112050_11750_val_acc_1.00_val_loss_0.002261.index
#
# N3D7_1_2001112050_11750_val_acc_1.00_val_loss_0.002261.meta
#  --> N3D7_sm_2001112050_11750_val_acc_1.00_val_loss_0.002261.meta
#
# N3D7_1_2001112106_12660_val_acc_1.00_val_loss_0.001616.data-00000-of-00001
# ...

# %%
files6 = sorted(listdir('.'))

# %%
files6
# Out:
# ['.ipynb_checkpoints',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.data-00000-of-00001',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.index',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.meta',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.data-00000-of-00001',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.index',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.meta',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.data-00000-of-00001',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.index',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.meta',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.data-00000-of-00001',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.index',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.meta',
#  'B_2001060534_13690_val_acc_1.00_val_loss_0.006853.data-00000-of-00001',
#  'B_2001060534_13690_val_acc_1.00_val_loss_0.006853.index',
# ...

# %%
for filename in files6:
    if 'NH_core' in filename:
        new_filename = filename.replace('NH_core', 'NH_sm_core')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    if 'ND_core' in filename:
        new_filename = filename.replace('ND_core', 'ND_sm_core')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    if 'B_core' in filename:
        new_filename = filename.replace('B_core', 'B_sm_core')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# B_core_2001120204_5000_val_acc_0.94_val_loss_0.130928.data-00000-of-00001
#  --> B_sm_core_2001120204_5000_val_acc_0.94_val_loss_0.130928.data-00000-of-00001
#
# B_core_2001120204_5000_val_acc_0.94_val_loss_0.130928.index
#  --> B_sm_core_2001120204_5000_val_acc_0.94_val_loss_0.130928.index
#
# B_core_2001120204_5000_val_acc_0.94_val_loss_0.130928.meta
#  --> B_sm_core_2001120204_5000_val_acc_0.94_val_loss_0.130928.meta
#
# ND_core_2001120244_7000_val_acc_0.91_val_loss_0.419095.data-00000-of-00001
#  --> ND_sm_core_2001120244_7000_val_acc_0.91_val_loss_0.419095.data-00000-of-00001
#
# ND_core_2001120244_7000_val_acc_0.91_val_loss_0.419095.index
#  --> ND_sm_core_2001120244_7000_val_acc_0.91_val_loss_0.419095.index
#
# ND_core_2001120244_7000_val_acc_0.91_val_loss_0.419095.meta
#  --> ND_sm_core_2001120244_7000_val_acc_0.91_val_loss_0.419095.meta
#
# NH_core_2001121427_5000_val_acc_0.99_val_loss_0.013037.data-00000-of-00001
# ...

# %%
files7 = sorted(listdir('.'))

# %%
files7
# Out:
# ['.ipynb_checkpoints',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.data-00000-of-00001',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.index',
#  'B_2001060434_9410_val_acc_1.00_val_loss_0.019657.meta',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.data-00000-of-00001',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.index',
#  'B_2001060441_9870_val_acc_1.00_val_loss_0.011613.meta',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.data-00000-of-00001',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.index',
#  'B_2001060509_11910_val_acc_1.00_val_loss_0.009551.meta',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.data-00000-of-00001',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.index',
#  'B_2001060518_12540_val_acc_1.00_val_loss_0.008383.meta',
#  'B_2001060534_13690_val_acc_1.00_val_loss_0.006853.data-00000-of-00001',
#  'B_2001060534_13690_val_acc_1.00_val_loss_0.006853.index',
# ...

# %%
for filename in files7:
    if 'NH_200' in filename:
        new_filename = filename.replace('NH_200', 'NH_sm_v2_200')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    if 'ND_200' in filename:
        new_filename = filename.replace('ND_200', 'ND_sm_v2_200')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    if 'B_200' in filename:
        new_filename = filename.replace('B_200', 'B_sm_v2_200')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# B_2001060434_9410_val_acc_1.00_val_loss_0.019657.data-00000-of-00001
#  --> B_sm_v2_2001060434_9410_val_acc_1.00_val_loss_0.019657.data-00000-of-00001
#
# B_2001060434_9410_val_acc_1.00_val_loss_0.019657.index
#  --> B_sm_v2_2001060434_9410_val_acc_1.00_val_loss_0.019657.index
#
# B_2001060434_9410_val_acc_1.00_val_loss_0.019657.meta
#  --> B_sm_v2_2001060434_9410_val_acc_1.00_val_loss_0.019657.meta
#
# B_2001060441_9870_val_acc_1.00_val_loss_0.011613.data-00000-of-00001
#  --> B_sm_v2_2001060441_9870_val_acc_1.00_val_loss_0.011613.data-00000-of-00001
#
# B_2001060441_9870_val_acc_1.00_val_loss_0.011613.index
#  --> B_sm_v2_2001060441_9870_val_acc_1.00_val_loss_0.011613.index
#
# B_2001060441_9870_val_acc_1.00_val_loss_0.011613.meta
#  --> B_sm_v2_2001060441_9870_val_acc_1.00_val_loss_0.011613.meta
#
# B_2001060509_11910_val_acc_1.00_val_loss_0.009551.data-00000-of-00001
#  --> B_sm_v2_2001060509_11910_val_acc_1.00_val_loss_0.009551.data-00000-of-00001
#
# ...

# %%
sorted(listdir('.'))
# Out:
# ['.ipynb_checkpoints',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.data-00000-of-00001',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.index',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.meta',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.data-00000-of-00001',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.index',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.meta',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.data-00000-of-00001',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.index',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.meta',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.data-00000-of-00001',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.index',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.meta',
#  'B_sm_2001112151_14470_val_acc_1.00_val_loss_0.000708.data-00000-of-00001',
#  'B_sm_2001112151_14470_val_acc_1.00_val_loss_0.000708.index',
# ...

# %% [markdown]
# ## datatype_model (B_sm -> ETIRE_B)

# %%
model_list = sorted(listdir('./model'))

# %%
model_list
# Out:
# ['.ipynb_checkpoints',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.data-00000-of-00001',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.index',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.meta',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.data-00000-of-00001',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.index',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.meta',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.data-00000-of-00001',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.index',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.meta',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.data-00000-of-00001',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.index',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.meta',
#  'B_sm_2001112151_14470_val_acc_1.00_val_loss_0.000708.data-00000-of-00001',
#  'B_sm_2001112151_14470_val_acc_1.00_val_loss_0.000708.index',
# ...

# %%
os.chdir('./model')

# %%
for filename in model_list:
    model = filename.split('_')[0]    
    if 'sm_core_rgb' in filename:
        new_filename = filename.replace(model + '_sm_core_rgb', 'CORE_rgb_' + model)
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# B_sm_core_rgb_2001041918_7510_val_acc_1.00_val_loss_0.004834.data-00000-of-00001
#  --> CORE_rgb_B_2001041918_7510_val_acc_1.00_val_loss_0.004834.data-00000-of-00001
#
# B_sm_core_rgb_2001041918_7510_val_acc_1.00_val_loss_0.004834.index
#  --> CORE_rgb_B_2001041918_7510_val_acc_1.00_val_loss_0.004834.index
#
# B_sm_core_rgb_2001041918_7510_val_acc_1.00_val_loss_0.004834.meta
#  --> CORE_rgb_B_2001041918_7510_val_acc_1.00_val_loss_0.004834.meta
#
# B_sm_core_rgb_2001041919_7670_val_acc_1.00_val_loss_0.001308.data-00000-of-00001
#  --> CORE_rgb_B_2001041919_7670_val_acc_1.00_val_loss_0.001308.data-00000-of-00001
#
# B_sm_core_rgb_2001041919_7670_val_acc_1.00_val_loss_0.001308.index
#  --> CORE_rgb_B_2001041919_7670_val_acc_1.00_val_loss_0.001308.index
#
# B_sm_core_rgb_2001041919_7670_val_acc_1.00_val_loss_0.001308.meta
#  --> CORE_rgb_B_2001041919_7670_val_acc_1.00_val_loss_0.001308.meta
#
# B_sm_core_rgb_2001041926_8400_val_acc_1.00_val_loss_0.000314.data-00000-of-00001
# ...

# %%
for filename in model_list:
    model = filename.split('_')[0]    
    if 'sm_rgb' in filename:
        new_filename = filename.replace(model + '_sm_rgb', 'ENTIRE_rgb_' + model)
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# B_sm_rgb_1908242109_8570_val_acc_1.00_val_loss_0.011026.data-00000-of-00001
#  --> ENTIRE_rgb_B_1908242109_8570_val_acc_1.00_val_loss_0.011026.data-00000-of-00001
#
# B_sm_rgb_1908242109_8570_val_acc_1.00_val_loss_0.011026.index
#  --> ENTIRE_rgb_B_1908242109_8570_val_acc_1.00_val_loss_0.011026.index
#
# B_sm_rgb_1908242109_8570_val_acc_1.00_val_loss_0.011026.meta
#  --> ENTIRE_rgb_B_1908242109_8570_val_acc_1.00_val_loss_0.011026.meta
#
# ND_sm_rgb_1908302155_7140_val_acc_1.00_val_loss_0.002939.data-00000-of-00001
#  --> ENTIRE_rgb_ND_1908302155_7140_val_acc_1.00_val_loss_0.002939.data-00000-of-00001
#
# ND_sm_rgb_1908302155_7140_val_acc_1.00_val_loss_0.002939.index
#  --> ENTIRE_rgb_ND_1908302155_7140_val_acc_1.00_val_loss_0.002939.index
#
# ND_sm_rgb_1908302155_7140_val_acc_1.00_val_loss_0.002939.meta
#  --> ENTIRE_rgb_ND_1908302155_7140_val_acc_1.00_val_loss_0.002939.meta
#
# NH_sm_rgb_1908312018_5750_val_acc_1.00_val_loss_0.001598.data-00000-of-00001
# ...

# %%
model_list = sorted(listdir('.'))

# %%
model_list
# Out:
# ['.ipynb_checkpoints',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.data-00000-of-00001',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.index',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.meta',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.data-00000-of-00001',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.index',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.meta',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.data-00000-of-00001',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.index',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.meta',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.data-00000-of-00001',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.index',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.meta',
#  'B_sm_2001112151_14470_val_acc_1.00_val_loss_0.000708.data-00000-of-00001',
#  'B_sm_2001112151_14470_val_acc_1.00_val_loss_0.000708.index',
# ...

# %%
for filename in model_list:
    model = filename.split('_')[0]    
    if 'sm_core' in filename:
        new_filename = filename.replace(model + '_sm_core', 'CORE_' + model)
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# ND_sm_core_2001120244_7000_val_acc_0.91_val_loss_0.419095.data-00000-of-00001
#  --> CORE_ND_2001120244_7000_val_acc_0.91_val_loss_0.419095.data-00000-of-00001
#
# ND_sm_core_2001120244_7000_val_acc_0.91_val_loss_0.419095.index
#  --> CORE_ND_2001120244_7000_val_acc_0.91_val_loss_0.419095.index
#
# ND_sm_core_2001120244_7000_val_acc_0.91_val_loss_0.419095.meta
#  --> CORE_ND_2001120244_7000_val_acc_0.91_val_loss_0.419095.meta
#
# NH_sm_core_2001121427_5000_val_acc_0.99_val_loss_0.013037.data-00000-of-00001
#  --> CORE_NH_2001121427_5000_val_acc_0.99_val_loss_0.013037.data-00000-of-00001
#
# NH_sm_core_2001121427_5000_val_acc_0.99_val_loss_0.013037.index
#  --> CORE_NH_2001121427_5000_val_acc_0.99_val_loss_0.013037.index
#
# NH_sm_core_2001121427_5000_val_acc_0.99_val_loss_0.013037.meta
#  --> CORE_NH_2001121427_5000_val_acc_0.99_val_loss_0.013037.meta

# %%
model_list = sorted(listdir('.'))

for filename in model_list:
    model = filename.split('_')[0]    
    if 'sm_diff' in filename:
        new_filename = filename.replace(model + '_sm_diff', 'DIFF_' + model)
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# B_sm_diff_2001140227_2430_val_mean_loss_0.344034.data-00000-of-00001
#  --> DIFF_B_2001140227_2430_val_mean_loss_0.344034.data-00000-of-00001
#
# B_sm_diff_2001140227_2430_val_mean_loss_0.344034.index
#  --> DIFF_B_2001140227_2430_val_mean_loss_0.344034.index
#
# B_sm_diff_2001140227_2430_val_mean_loss_0.344034.meta
#  --> DIFF_B_2001140227_2430_val_mean_loss_0.344034.meta
#
# B_sm_diff_2001140228_2460_val_mean_loss_0.339793.data-00000-of-00001
#  --> DIFF_B_2001140228_2460_val_mean_loss_0.339793.data-00000-of-00001
#
# B_sm_diff_2001140228_2460_val_mean_loss_0.339793.index
#  --> DIFF_B_2001140228_2460_val_mean_loss_0.339793.index
#
# B_sm_diff_2001140228_2460_val_mean_loss_0.339793.meta
#  --> DIFF_B_2001140228_2460_val_mean_loss_0.339793.meta
#
# B_sm_diff_2001140244_3330_val_mean_loss_0.339760.data-00000-of-00001
#  --> DIFF_B_2001140244_3330_val_mean_loss_0.339760.data-00000-of-00001
#
# B_sm_diff_2001140244_3330_val_mean_loss_0.339760.index
# ...

# %%
sorted(listdir('.'))
# Out:
# ['.ipynb_checkpoints',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.data-00000-of-00001',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.index',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.meta',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.data-00000-of-00001',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.index',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.meta',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.data-00000-of-00001',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.index',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.meta',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.data-00000-of-00001',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.index',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.meta',
#  'B_sm_2001112151_14470_val_acc_1.00_val_loss_0.000708.data-00000-of-00001',
#  'B_sm_2001112151_14470_val_acc_1.00_val_loss_0.000708.index',
# ...

# %%
model_list = sorted(listdir('.'))

for filename in model_list:
    model = filename.split('_')[0]    
    if 'sm_v2' in filename:
        new_filename = filename.replace(model + '_sm_v2', 'ENTIRE2_' + model)
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# B_sm_v2_2001060434_9410_val_acc_1.00_val_loss_0.019657.data-00000-of-00001
#  --> ENTIRE2_B_2001060434_9410_val_acc_1.00_val_loss_0.019657.data-00000-of-00001
#
# B_sm_v2_2001060434_9410_val_acc_1.00_val_loss_0.019657.index
#  --> ENTIRE2_B_2001060434_9410_val_acc_1.00_val_loss_0.019657.index
#
# B_sm_v2_2001060434_9410_val_acc_1.00_val_loss_0.019657.meta
#  --> ENTIRE2_B_2001060434_9410_val_acc_1.00_val_loss_0.019657.meta
#
# B_sm_v2_2001060441_9870_val_acc_1.00_val_loss_0.011613.data-00000-of-00001
#  --> ENTIRE2_B_2001060441_9870_val_acc_1.00_val_loss_0.011613.data-00000-of-00001
#
# B_sm_v2_2001060441_9870_val_acc_1.00_val_loss_0.011613.index
#  --> ENTIRE2_B_2001060441_9870_val_acc_1.00_val_loss_0.011613.index
#
# B_sm_v2_2001060441_9870_val_acc_1.00_val_loss_0.011613.meta
#  --> ENTIRE2_B_2001060441_9870_val_acc_1.00_val_loss_0.011613.meta
#
# B_sm_v2_2001060509_11910_val_acc_1.00_val_loss_0.009551.data-00000-of-00001
# ...

# %%
sorted(listdir('.'))
# Out:
# ['.ipynb_checkpoints',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.data-00000-of-00001',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.index',
#  'B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.meta',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.data-00000-of-00001',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.index',
#  'B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.meta',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.data-00000-of-00001',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.index',
#  'B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.meta',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.data-00000-of-00001',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.index',
#  'B_sm_2001112127_13190_val_acc_1.00_val_loss_0.001404.meta',
#  'B_sm_2001112151_14470_val_acc_1.00_val_loss_0.000708.data-00000-of-00001',
#  'B_sm_2001112151_14470_val_acc_1.00_val_loss_0.000708.index',
# ...

# %%
model_list = sorted(listdir('.'))

for filename in model_list:
    model = filename.split('_')[0]    
    if 'sm' in filename:
        new_filename = filename.replace(model + '_sm', 'ENTIRE_' + model)
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.data-00000-of-00001
#  --> ENTIRE_B_2001112003_8680_val_acc_1.00_val_loss_0.002840.data-00000-of-00001
#
# B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.index
#  --> ENTIRE_B_2001112003_8680_val_acc_1.00_val_loss_0.002840.index
#
# B_sm_2001112003_8680_val_acc_1.00_val_loss_0.002840.meta
#  --> ENTIRE_B_2001112003_8680_val_acc_1.00_val_loss_0.002840.meta
#
# B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.data-00000-of-00001
#  --> ENTIRE_B_2001112051_11240_val_acc_1.00_val_loss_0.002717.data-00000-of-00001
#
# B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.index
#  --> ENTIRE_B_2001112051_11240_val_acc_1.00_val_loss_0.002717.index
#
# B_sm_2001112051_11240_val_acc_1.00_val_loss_0.002717.meta
#  --> ENTIRE_B_2001112051_11240_val_acc_1.00_val_loss_0.002717.meta
#
# B_sm_2001112054_11400_val_acc_1.00_val_loss_0.002119.data-00000-of-00001
# ...

# %%
sorted(listdir('.'))
# Out:
# ['.ipynb_checkpoints',
#  'CORE_B_2001120204_5000_val_acc_0.94_val_loss_0.130928.data-00000-of-00001',
#  'CORE_B_2001120204_5000_val_acc_0.94_val_loss_0.130928.index',
#  'CORE_B_2001120204_5000_val_acc_0.94_val_loss_0.130928.meta',
#  'CORE_ND_2001120244_7000_val_acc_0.91_val_loss_0.419095.data-00000-of-00001',
#  'CORE_ND_2001120244_7000_val_acc_0.91_val_loss_0.419095.index',
#  'CORE_ND_2001120244_7000_val_acc_0.91_val_loss_0.419095.meta',
#  'CORE_NH_2001121427_5000_val_acc_0.99_val_loss_0.013037.data-00000-of-00001',
#  'CORE_NH_2001121427_5000_val_acc_0.99_val_loss_0.013037.index',
#  'CORE_NH_2001121427_5000_val_acc_0.99_val_loss_0.013037.meta',
#  'CORE_rgb_B_2001041918_7510_val_acc_1.00_val_loss_0.004834.data-00000-of-00001',
#  'CORE_rgb_B_2001041918_7510_val_acc_1.00_val_loss_0.004834.index',
#  'CORE_rgb_B_2001041918_7510_val_acc_1.00_val_loss_0.004834.meta',
#  'CORE_rgb_B_2001041919_7670_val_acc_1.00_val_loss_0.001308.data-00000-of-00001',
# ...

# %% [markdown]
# ## X160 model

# %%
os.chdir('./model')
os.listdir('.')
# Out:
# ['ENTIRE_rgb_ND_1908302155_7140_val_acc_1.00_val_loss_0.002939.meta',
#  'CORE_B_2001120204_5000_val_acc_0.94_val_loss_0.130928.index',
#  'ENTIRE_rgb_B_1908242109_8570_val_acc_1.00_val_loss_0.011026.meta',
#  'ENTIRE_rgb_NH_1908312018_5750_val_acc_1.00_val_loss_0.001598.index',
#  'ENTIRE_rgb_NH_1908312018_5750_val_acc_1.00_val_loss_0.001598.meta',
#  'CORE_B_2001120204_5000_val_acc_0.94_val_loss_0.130928.data-00000-of-00001',
#  'CORE_B_2001120204_5000_val_acc_0.94_val_loss_0.130928.meta',
#  'CORE_rgb_NH_2001041909_8960_val_acc_1.00_val_loss_0.000000.data-00000-of-00001',
#  'checkpoint',
#  '.ipynb_checkpoints',
#  'ENTIRE2_B_2001100012_80_val_acc_0.60_val_loss_0.659025.index',
#  'ENTIRE2_NH_2001081619_3800_val_acc_0.97_val_loss_0.054612.meta',
#  'ENTIRE2_NH_2001100015_10_val_acc_0.51_val_loss_0.691620.meta',
#  'ENTIRE2_NH_2001062352_20490_val_acc_1.00_val_loss_0.000032.meta',
#  'ENTIRE2_NH_2001081636_5500_val_acc_0.99_val_loss_0.035910.index',
# ...

# %%
for filename in sorted(os.listdir('.')):
    if 'X160_NH' in filename: 
        new_filename = filename.replace('X160_NH', 'X160_NX40H')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    elif 'X160_ND' in filename: 
        new_filename = filename.replace('X160_ND', 'X160_NX40D')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
    elif 'X160_B' in filename: 
        new_filename = filename.replace('X160_B', 'X160_NX40A')
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# X160_B_2001161417_800_val_acc_0.93_val_loss_0.164143.data-00000-of-00001
#  --> X160_NX40A_2001161417_800_val_acc_0.93_val_loss_0.164143.data-00000-of-00001
#
# X160_B_2001161417_800_val_acc_0.93_val_loss_0.164143.index
#  --> X160_NX40A_2001161417_800_val_acc_0.93_val_loss_0.164143.index
#
# X160_B_2001161417_800_val_acc_0.93_val_loss_0.164143.meta
#  --> X160_NX40A_2001161417_800_val_acc_0.93_val_loss_0.164143.meta
#
# X160_B_2001161417_810_val_acc_0.95_val_loss_0.158911.data-00000-of-00001
#  --> X160_NX40A_2001161417_810_val_acc_0.95_val_loss_0.158911.data-00000-of-00001
#
# X160_B_2001161417_810_val_acc_0.95_val_loss_0.158911.index
#  --> X160_NX40A_2001161417_810_val_acc_0.95_val_loss_0.158911.index
#
# X160_B_2001161417_810_val_acc_0.95_val_loss_0.158911.meta
#  --> X160_NX40A_2001161417_810_val_acc_0.95_val_loss_0.158911.meta
#
# X160_B_2001161419_910_val_acc_0.98_val_loss_0.109640.data-00000-of-00001
# ...
