# %%
# !nvidia-smi
# Out:
# Wed Jan 22 10:58:51 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.26       Driver Version: 430.26       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  Off  | 00000000:1D:00.0 Off |                  N/A |
# | 27%   33C    P0    52W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  Off  | 00000000:1E:00.0 Off |                  N/A |
# | 27%   33C    P0    59W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  Off  | 00000000:1F:00.0 Off |                  N/A |
# | 26%   32C    P0    62W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 208...  Off  | 00000000:20:00.0 Off |                  N/A |
# | 28%   31C    P0    63W / 250W |      0MiB / 11019MiB |      1%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce RTX 208...  Off  | 00000000:21:00.0 Off |                  N/A |
# | 27%   27C    P8    25W / 250W |  10665MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce RTX 208...  Off  | 00000000:22:00.0 Off |                  N/A |
# | 30%   45C    P2    78W / 250W |  10925MiB / 11019MiB |     32%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce RTX 208...  Off  | 00000000:23:00.0 Off |                  N/A |
# | 29%   33C    P0    56W / 250W |      0MiB / 11019MiB |      1%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  GeForce RTX 208...  Off  | 00000000:24:00.0 Off |                  N/A |
# | 16%   34C    P0     1W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    4      9736      C   /usr/bin/python3                           10655MiB |
# |    5     18983      C   /usr/bin/python3                           10915MiB |
# +-----------------------------------------------------------------------------+

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="3"

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import time, datetime

import sys
sys.path.append('/mnt/disk1/project/SMhospital/capsule/ce_packages')
from ce_utils import load_path, train_valid_split, damped_exp_LR, load_random_minibatch, shuffle
from ce_utils import training_history
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Load Data

# %%
from itertools import product
import glob

def target_preprocessings(phase_a_switch = [1, 1, 1], phase_b_switch = True, mode = 'load'):
    """
    phase_a_switch = [1, 1, 1], [0, 0 ,1], [1, 1, 0].... 
    that means [flip, rotate, blur_sharp]
    """
    phase0 = ['_c']
    phase1 = {1: ['-', 'f'], 0: ['-']}
    phase2 = {1: ['-', 'r1', 'r2', 'r3'], 0: ['-']}
    phase3 = {1: ['-', 'ab', 'mb', 'eh'], 0: ['-']}
    phase4 = ['s_-30_v_30', 's_-30_v_-30', 's_30_v_-30', 's_30_v_30']
    
    if mode == 'load':
        phase_a_items = [phase1[phase_a_switch[0]], phase2[phase_a_switch[1]], phase3[phase_a_switch[2]]]
    elif mode == 'preprocessing':
        phase_a_items = [phase0, phase1[phase_a_switch[0]], phase2[phase_a_switch[1]], phase3[phase_a_switch[2]]]
    
    phase_a = []
    for i in list(product(*phase_a_items)):
        phase_a.append('_'.join(i))

    if not phase_b_switch != True:
        phase_b = []
        for i in list(product(*[phase_a, phase4])):
            phase_b.append('_'.join(i))
        return list(np.hstack([phase_a, phase_b]))
    else:
        return phase_a 

class ce_load_dataset:
    def __init__(self, phase, data, pre_a, pre_b, img_ch = 'bgr', ext_name = True):
        self.phase = phase        # 'train' or 'test'
        self.data = data          # 'sm', 'sm_core', 'sm_v2', 'sm_x160', ...
        self.pre_a = pre_a        # [1, 1, 1], [0, 0 ,1], [1, 1, 0].... 
        self.pre_b = pre_b        # True or False
        self.img_ch = img_ch      # 'bgr', 'rgb', and 'hsv'
        self.ext_name = ext_name  # True or False

    def load_path(self, cls, les, data_dir = '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed'):
        """
        phase = 'train', 'test'
        cls: [les]  
          'n': ['neg']
          'h': ['redspot', 'angio', 'active'], 
          'd': ['ero', 'ulc', 'str'],
          'p': ['amp', 'lym', 'tum']}
        pre_a[0] must be 0
        """
        lesions = dict(neg = 'negative', 
                       redspot = 'red_spot', angio = 'angioectasia', active = 'active_bleeding', 
                       ero = 'erosion', ulcer = 'ulcer', str = 'stricture', 
                       amp = 'ampulla_of_vater', lym = 'lymphoid_follicles', tum = 'small_bowel_tumor')
        classes = dict(n = 'negative', h = 'hemorrhagic', d = 'depressed', p = 'protruded')

        path = os.path.join(data_dir, self.data, self.phase, classes[cls], lesions[les])
        pathlist = glob.glob(path + '/*.jpg')
        if self.pre_b != True:
            path_in_phase = []
            for p in pathlist:
                name = os.path.basename(p)
                if (name.split('c_')[-1])[:-4] in target_preprocessings(self.pre_a, self.pre_b):
                    path_in_phase.append(p)   
            return np.asarray(path_in_phase)
        else:
            return np.asarray(pathlist)

    def load_image_from_path(self, pathlist,image_ch = 'bgr', extract_name = False):
        data = []
        for i in pathlist:
            temp = cv2.imread(i)
            if image_ch == 'bgr':
                pass
            elif image_ch == 'rgb':
                temp = cv2.cvtColor(temp, cv2.COLOR_BGR2RGB)
            elif image_ch == 'hsv':
                temp = cv2.cvtColor(temp, cv2.COLOR_BGR2HSV)
            data.append(temp)
        if extract_name != False:
            name = []
            for i in pathlist:
                name.append(os.path.basename(i))
            return np.asarray(data), np.asarray(name)
        else:
            return np.asarray(data) 

    def load_data(self, cls, les):
        pathlist = self.load_path(cls, les)
        return  self.load_image_from_path(pathlist, image_ch = self.img_ch, extract_name = self.ext_name)

# %%
ce = ce_load_dataset(phase = 'train', data = 'sm_x160_v2', pre_a = [1, 1, 0], pre_b = False)

# %%
neg_path = ce.load_path('n', 'neg')
# redspot_path = ce.load_path('h', 'redspot')
# angio_path = ce.load_path('h', 'angio')
# active_path = ce.load_path('h', 'active')
ero_path = ce.load_path('d', 'ero')
ulcer_path = ce.load_path('d', 'ulcer')
str_path = ce.load_path('d', 'str')

print("negative:",neg_path.shape)
# print("red spot:",redspot_path.shape)
# print("angioectasia:",angio_path.shape)
# print("active_bleeding:",active_path.shape)
print("erosion:",ero_path.shape)
print("ulcer:",ulcer_path.shape)
print("stricture:",str_path.shape)
# Out:
# negative: (49952,)
# erosion: (5896,)
# ulcer: (5856,)
# stricture: (824,)

# %%
str_path
# Out:
# array(['/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-57-58___1064571__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-57-58___1064571__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-57-58___1064571__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-57-58___1064571__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-57-58___1064571__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-57-58___1064571__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-57-58___1064571__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-57-58___1064571__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-34___1044835__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-34___1044835__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-34___1044835__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-34___1044835__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-34___1044835__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-34___1044835__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-34___1044835__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-34___1044835__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-10-04___1073221__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-10-04___1073221__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-10-04___1073221__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-10-04___1073221__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-10-04___1073221__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-10-04___1073221__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-10-04___1073221__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-10-04___1073221__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-08___2093086__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-08___2093086__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-08___2093086__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-08___2093086__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-08___2093086__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-08___2093086__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-08___2093086__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-08___2093086__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-45-22___1041450__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-45-22___1041450__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-45-22___1041450__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-45-22___1041450__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-45-22___1041450__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-45-22___1041450__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-45-22___1041450__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-45-22___1041450__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-11-08___1037340__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-11-08___1037340__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-11-08___1037340__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-11-08___1037340__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-11-08___1037340__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-11-08___1037340__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-11-08___1037340__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-11-08___1037340__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-44___1044854__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-44___1044854__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-44___1044854__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-44___1044854__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-44___1044854__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-44___1044854__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-44___1044854__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-44___1044854__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-13-58___1052085__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-13-58___1052085__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KI___04-35-35___1033078__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-13-58___1052085__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-13-58___1052085__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-13-58___1052085__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-13-58___1052085__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-13-58___1052085__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-13-58___1052085__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/오김___07-00-04___2059782__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/오김___07-00-04___2059782__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/오김___07-00-04___2059782__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/오김___07-00-04___2059782__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/오김___07-00-04___2059782__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/오김___07-00-04___2059782__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KI___04-35-35___1033078__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/오김___07-00-04___2059782__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/오김___07-00-04___2059782__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KI___04-35-35___1033078__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KI___04-35-35___1033078__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KI___04-35-35___1033078__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KI___04-35-35___1033078__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KI___04-35-35___1033078__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KI___04-35-35___1033078__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-10___1036744__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-10___1036744__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-10___1036744__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-10___1036744__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-10___1036744__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-10___1036744__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-10___1036744__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-10___1036744__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-12-40___1037525__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-12-40___1037525__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KH___01-22-09___1009859__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-12-40___1037525__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-12-40___1037525__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-12-40___1037525__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-12-40___1037525__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-12-40___1037525__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-12-40___1037525__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KH___01-22-09___1009859__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KH___01-22-09___1009859__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KH___01-22-09___1009859__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KH___01-22-09___1009859__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KH___01-22-09___1009859__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KH___01-22-09___1009859__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/KH___01-22-09___1009859__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-31-26___1039776__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-31-26___1039776__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-31-26___1039776__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-31-26___1039776__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-31-26___1039776__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-31-26___1039776__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-31-26___1039776__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-31-26___1039776__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-47___1036819__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-47___1036819__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-47___1036819__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-47___1036819__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-47___1036819__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-47___1036819__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-47___1036819__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-47___1036819__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-02-26___1043498__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-02-26___1043498__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-02-26___1043498__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-02-26___1043498__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-02-26___1043498__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-02-26___1043498__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-02-26___1043498__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-02-26___1043498__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-44-55___1063005__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-44-55___1063005__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-44-55___1063005__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-44-55___1063005__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-44-55___1063005__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-44-55___1063005__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-44-55___1063005__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___08-44-55___1063005__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-26___2106685__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-26___2106685__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-26___2106685__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-26___2106685__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-26___2106685__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-26___2106685__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-26___2106685__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-26___2106685__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-23___1036771__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-23___1036771__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-23___1036771__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-23___1036771__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-23___1036771__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-23___1036771__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-23___1036771__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-06-23___1036771__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-22___2093113__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-22___2093113__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-22___2093113__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-22___2093113__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-22___2093113__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-22___2093113__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-22___2093113__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-21-17___1038560__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___10-33-22___2093113__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___05-24-18___1038917__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___05-24-18___1038917__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___05-24-18___1038917__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___05-24-18___1038917__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___05-24-18___1038917__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___05-24-18___1038917__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___05-24-18___1038917__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___05-24-18___1038917__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___09-23-34___2084719__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___09-23-34___2084719__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___09-23-34___2084719__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___09-23-34___2084719__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___09-23-34___2084719__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___09-23-34___2084719__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___09-23-34___2084719__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-21-17___1038560__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___09-23-34___2084719__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-11-16___1073364__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-21-17___1038560__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-21-17___1038560__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-21-17___1038560__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-21-17___1038560__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-21-17___1038560__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-21-17___1038560__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___04-24-21___1031722__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___04-24-21___1031722__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___04-24-21___1031722__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___04-24-21___1031722__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___04-24-21___1031722__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___04-24-21___1031722__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___04-24-21___1031722__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/승한___04-24-21___1031722__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-57-32___1035708__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-57-32___1035708__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-57-32___1035708__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-57-32___1035708__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-11-16___1073364__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-57-32___1035708__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-57-32___1035708__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-57-32___1035708__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___09-12-57___1066368__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-57-32___1035708__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-11-16___1073364__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-11-16___1073364__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-11-16___1073364__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-11-16___1073364__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-11-16___1073364__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___10-11-16___1073364__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-08-44___2064629__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-08-44___2064629__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-08-44___2064629__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-08-44___2064629__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-08-44___2064629__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-08-44___2064629__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-08-44___2064629__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___09-12-57___1066368__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-08-44___2064629__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-53-04___2050337__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-53-04___2050337__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-53-04___2050337__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-53-04___2050337__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-53-04___2050337__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-53-04___2050337__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-53-04___2050337__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-53-04___2050337__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-59-25___1050337__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___11-28-13___2099676__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___11-28-13___2099676__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___11-28-13___2099676__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___11-28-13___2099676__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___11-28-13___2099676__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___11-28-13___2099676__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-59-25___1050337__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___11-28-13___2099676__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___11-28-13___2099676__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-38-36___2041020__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-38-36___2041020__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-38-36___2041020__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-38-36___2041020__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-38-36___2041020__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-38-36___2041020__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-38-36___2041020__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-48___1044862__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-38-36___2041020__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___05-16-45___2053280__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___05-16-45___2053280__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___05-16-45___2053280__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___05-16-45___2053280__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___05-16-45___2053280__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___05-16-45___2053280__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-13-48___1044862__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___05-16-45___2053280__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___05-16-45___2053280__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___09-12-57___1066368__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___09-12-57___1066368__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___09-12-57___1066368__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___09-12-57___1066368__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___09-12-57___1066368__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___09-12-57___1066368__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-30___2106692__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-30___2106692__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-30___2106692__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-30___2106692__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-30___2106692__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-30___2106692__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-30___2106692__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-30___2106692__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-35-48___1040301__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___06-01-00___2060421__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___06-01-00___2060421__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___06-01-00___2060421__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___06-01-00___2060421__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___06-01-00___2060421__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___06-01-00___2060421__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-35-48___1040301__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___06-01-00___2060421__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___06-01-00___2060421__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-13-04___1037572__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-59-25___1050337__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-59-25___1050337__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-59-25___1050337__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-59-25___1050337__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-59-25___1050337__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___06-59-25___1050337__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-12-01___2065056__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-12-01___2065056__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-12-01___2065056__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-12-01___2065056__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-12-01___2065056__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-12-01___2065056__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-13-04___1037572__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-12-01___2065056__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-12-01___2065056__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-49-28___1034741__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-49-28___1034741__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-49-28___1034741__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-49-28___1034741__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-49-28___1034741__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-49-28___1034741__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-49-28___1034741__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-49-28___1034741__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-46-19___1034362__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-46-19___1034362__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-46-19___1034362__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-46-19___1034362__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-46-19___1034362__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-46-19___1034362__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-46-19___1034362__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___04-46-19___1034362__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-09-16___2064693__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-09-16___2064693__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-09-16___2064693__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-09-16___2064693__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-09-16___2064693__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-09-16___2064693__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___12-19-57___1088810__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-09-16___2064693__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-09-16___2064693__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-01-36___1036196__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-01-36___1036196__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___12-19-57___1088810__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-01-36___1036196__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/순황___05-01-36___1036196__c_f_r1_-.jpg',
# ...
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___11-45-53___1084722__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___11-28-52___2099754__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___11-28-52___2099754__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/성서___03-10-44___1022891__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/성서___03-10-44___1022891__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/성서___03-10-44___1022891__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/성서___03-10-44___1022891__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/성서___03-10-44___1022891__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/성서___03-10-44___1022891__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/성서___03-10-44___1022891__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___06-48-50___1049071__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/성서___03-10-44___1022891__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___08-41-41___1062612__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___08-41-41___1062612__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___08-41-41___1062612__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___08-41-41___1062612__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___08-41-41___1062612__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___08-41-41___1062612__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106732__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106732__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106732__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106732__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106732__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106732__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106732__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___06-48-50___1049071__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106732__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106733__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106733__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106733__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106733__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106733__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106733__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106733__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-50___2106733__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-56-35___1042796__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-56-35___1042796__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-56-35___1042796__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-56-35___1042796__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-56-35___1042796__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___05-56-35___1042796__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-46___2106725__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-46___2106725__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-46___2106725__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-46___2106725__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-46___2106725__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-46___2106725__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-46___2106725__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/철김___12-26-46___2106725__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-20-28___1052864__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-20-28___1052864__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-20-28___1052864__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-20-28___1052864__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-20-28___1052864__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___07-20-28___1052864__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-39-10___2041089__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-39-10___2041089__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-39-10___2041089__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-39-10___2041089__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-39-10___2041089__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-39-10___2041089__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-39-10___2041089__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___03-39-10___2041089__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-10-23___2064828__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-10-23___2064828__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-10-23___2064828__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-10-23___2064828__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-10-23___2064828__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-10-23___2064828__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-10-23___2064828__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/숙황___07-10-23___2064828__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/기김___00-19-29___2005834_mild oozing at bulb__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___12-37-43___2108018__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/기김___00-19-29___2005834_mild oozing at bulb__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/기김___00-19-29___2005834_mild oozing at bulb__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/기김___00-19-29___2005834_mild oozing at bulb__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/기김___00-19-29___2005834_mild oozing at bulb__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/기김___00-19-29___2005834_mild oozing at bulb__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/기김___00-19-29___2005834_mild oozing at bulb__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/기김___00-19-29___2005834_mild oozing at bulb__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___12-37-43___2108018__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___12-37-43___2108018__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___12-37-43___2108018__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___12-37-43___2108018__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___12-37-43___2108018__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___12-37-43___2108018__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/광배___12-37-43___2108018__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___11-45-53___1084722__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___11-45-53___1084722__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___11-45-53___1084722__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___11-45-53___1084722__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___11-45-53___1084722__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/GK___11-45-53___1084722__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-50-33___2050027__c_-_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-50-33___2050027__c_f_-_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-50-33___2050027__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-50-33___2050027__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-50-33___2050027__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-50-33___2050027__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-50-33___2050027__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/영윤___04-50-33___2050027__c_f_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___06-48-50___1049071__c_-_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___06-48-50___1049071__c_f_r1_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___06-48-50___1049071__c_-_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___06-48-50___1049071__c_f_r2_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___06-48-50___1049071__c_-_r3_-.jpg',
#        '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed/sm_x160_v2/train/depressed/stricture/LS___06-48-50___1049071__c_f_r3_-.jpg'],
#       dtype='<U162')

# %%
neg_train_path, neg_valid_path = train_valid_split(neg_path, train_rate = 0.9)
# redspot_train_path, redspot_valid_path = train_valid_split(redspot_path, train_rate = 0.9)
# angio_train_path, angio_valid_path = train_valid_split(angio_path, train_rate = 0.9)
# active_train_path, active_valid_path = train_valid_split(active_path, train_rate = 0.9)
ero_train_path, ero_valid_path = train_valid_split(ero_path, train_rate = 0.9)
ulcer_train_path, ulcer_valid_path = train_valid_split(ulcer_path, train_rate = 0.9)
str_train_path, str_valid_path = train_valid_split(str_path, train_rate = 0.9)

print("negative:", neg_train_path.shape, neg_valid_path.shape)
# print("red spot:", redspot_train_path.shape, redspot_valid_path.shape)
# print("angioectasia:", angio_train_path.shape, angio_valid_path.shape)
# print("active bleeding:", active_train_path.shape, active_valid_path.shape)
print("erosion:", ero_train_path.shape, ero_valid_path.shape)
print("ulcer:", ulcer_train_path.shape, ulcer_valid_path.shape)
print("stricture:", str_train_path.shape, str_valid_path.shape)
# Out:
# negative: (44956,) (4480,)
# erosion: (5306,) (532,)
# ulcer: (5270,) (536,)
# stricture: (741,) (74,)

# %% [markdown]
# # Model

# %%
input_h = 512
input_w = 512
input_ch = 3

k_chs = [16, 16, 16, 32, 32, 32, 64]
n_conv_block = len(k_chs)
n_hid_node = [100, 50]
n_hid_layer = len(n_hid_node)
n_output = 2

# %%
class CE_cnn:
    def __init__(self, k_chs, n_conv_block, n_hid_node, n_hid_layer, n_output):
        self.k_chs = k_chs
        self.n_conv_block = n_conv_block
        self.n_hid_node = n_hid_node
        self.n_hid_layer = n_hid_layer
        self.n_output = n_output
    def conv_block(self, x, k_chs, n_conv_block):
        for i in range(1, n_conv_block + 1):
            if i == 1:
                conv = tf.layers.conv2d(inputs = x, filters = k_chs[i-1], kernel_size = [3, 3], padding = "SAME", 
                                        activation= tf.nn.relu, name = 'block_{}_conv_1'.format(i))
            else:
                conv = tf.layers.conv2d(inputs = conv, filters = k_chs[i-1], kernel_size = [3, 3], padding = "SAME", 
                                        activation= tf.nn.relu, name = 'block_{}_conv_1'.format(i))
            conv = tf.layers.conv2d(inputs = conv, filters = k_chs[i-1], kernel_size = [3, 3], padding = "SAME", 
                                    activation= tf.nn.relu, name = 'block_{}_conv_2'.format(i))
            conv = tf.layers.max_pooling2d(inputs = conv, pool_size = [2, 2], strides = 2, name = 'block_{}_maxp'.format(i))
        return conv
    def fc_layers(self, x, n_hid_node, n_hid_layer, n_output):
        hidden = tf.layers.flatten(x)
        for i in range(1, n_hid_layer + 1):
            hidden = tf.layers.dense(inputs = hidden, units = n_hid_node[i-1],activation = tf.nn.relu, name = 'fc_{}'.format(i))
            hidden = tf.layers.dropout(hidden, rate = 0.3, training = is_training)
        score = tf.layers.dense(inputs = hidden, units = n_output, name = 'score')
        return score
    
    def inf(self, x):
        conv = self.conv_block(x, self.k_chs, self.n_conv_block)
        score = self.fc_layers(conv, self.n_hid_node, self.n_hid_layer, self.n_output)
        return score

# %%
tf.reset_default_graph()

x = tf.placeholder(tf.float32, [None, input_h, input_w, input_ch], name = 'img')
y = tf.placeholder(tf.float32, [None, n_output], name = 'label')
#rate = tf.placeholder(tf.float32, name = 'rate') # tf.layers.dropout용 얼만큼 드랍아웃할건지
is_training = tf.placeholder(tf.bool, name = 'is_training')
LR = tf.placeholder(tf.float32)

model = CE_cnn(k_chs, n_conv_block, n_hid_node, n_hid_layer, n_output)
score = model.inf(x)
loss = tf.losses.softmax_cross_entropy(onehot_labels=y, logits=score)
loss = tf.reduce_mean(loss)

# update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
# with tf.control_dependencies(update_ops):
#     optm = tf.train.AdamOptimizer(learning_rate=lr).minimize(loss)
optm = tf.train.AdamOptimizer(LR).minimize(loss)

saver = tf.train.Saver()
sess = tf.Session()

init = tf.global_variables_initializer()
sess.run(init)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0122 10:59:50.952949 139675336218368 deprecation.py:323] From <ipython-input-10-147423120551>:12: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# W0122 10:59:50.962069 139675336218368 deprecation.py:506] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0122 10:59:51.184772 139675336218368 deprecation.py:323] From <ipython-input-10-147423120551>:18: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# W0122 10:59:51.468795 139675336218368 deprecation.py:323] From <ipython-input-10-147423120551>:21: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# W0122 10:59:51.676295 139675336218368 deprecation.py:323] From <ipython-input-10-147423120551>:23: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0122 10:59:52.042860 139675336218368 deprecation.py:323] From <ipython-input-10-147423120551>:24: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# W0122 10:59:52.159552 139675336218368 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# # Training

# %% [markdown]
# damped_exp_LR(20000, alpha = 0.0001) <br>
# n_batch (per class) = 50  <br>
# cal_interval = 10 <br>
# prt_interval = 100 <br>

# %%
d_train_path = np.hstack([ero_train_path, ulcer_train_path, str_train_path])
d_valid_path = np.hstack([ero_valid_path, ulcer_valid_path, str_valid_path])

a_train_path = shuffle(d_train_path, None)
a_valid_path = shuffle(d_valid_path, None)

# %%
damped_exp_LR
# Out:
# <function ce_utils.damped_exp_LR(n_iter, f=20, A=0.0005, alpha=0.0002, gamma=0.1)>

# %%
D_lr = damped_exp_LR(20000, alpha = 0.0001)

plt.plot(D_lr)

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

n_iter = 0
n_batch = 50
cal_interval = 10
prt_interval = 100
 
early_stopping = False
accr_train, accr_valid, loss_train, loss_valid = [], [], [], []
mean_accr_t, mean_accr_v, mean_loss_t, mean_loss_v = [], [], [], []
hist = training_history(accr_train, accr_valid, loss_train, loss_valid)
hist.table()

start_time = time.time()

while True:
    neg_train_x, neg_train_y = load_random_minibatch(neg_train_path, cls = 0, batch_size = n_batch)
    a_train_x, a_train_y = load_random_minibatch(a_train_path, cls = 1, batch_size = n_batch)
    train_x = np.vstack([neg_train_x, a_train_x])
    train_y = np.vstack([neg_train_y, a_train_y])
    train_x, train_y = shuffle(train_x, train_y)
    
    sess.run(optm, feed_dict = {'img:0': train_x, 'label:0': train_y, 'is_training:0' :1, LR: D_lr[n_iter]})
    n_iter += 1
    
    if n_iter % cal_interval == 0:
        c, p = sess.run([loss, score], feed_dict = {'img:0': train_x, 'label:0': train_y, 'is_training:0' :0})

        p = np.argmax(p, axis = 1)
        l = np.argmax(train_y, axis = 1)
        a = np.mean(np.equal(p, l))
        
        neg_valid_x, neg_valid_y = load_random_minibatch(neg_valid_path, cls = 0, batch_size = n_batch)
        a_valid_x, a_valid_y = load_random_minibatch(a_valid_path, cls = 1, batch_size = n_batch)
        valid_x = np.vstack([neg_valid_x, a_valid_x])
        valid_y = np.vstack([neg_valid_y, a_valid_y])
        
        c_valid, p_valid = sess.run([loss, score], feed_dict = {'img:0': valid_x, 'label:0': valid_y, 'is_training:0' :0})

        p_valid = np.argmax(p_valid, axis = 1)
        l_valid = np.argmax(valid_y, axis = 1)
        a_valid = np.mean(np.equal(p_valid, l_valid))

        accr_valid.append(a_valid)
        loss_valid.append(c_valid)
        accr_train.append(a)
        loss_train.append(c)

        if n_iter % prt_interval == 0:
            hist.prt_evl(n_iter)
        if n_iter >= 10:
            mean_accr_t.append(np.mean(accr_train[-10:])), mean_accr_v.append(np.mean(accr_valid[-10:]))
            mean_loss_t.append(np.mean(loss_train[-10:])), mean_loss_v.append(np.mean(loss_valid[-10:]))
        if mean_loss_v[-1] == np.min(mean_loss_v):
            now = datetime.datetime.now()
            nowDatetime = now.strftime('%y%m%d%H%M')
            model_name = 'X160_v2_fr_ND_{0}_{1}'.format(nowDatetime, n_iter)
            model_spec = 't_acc_{0:.2f}_v_acc_{1:.2f}_t_loss_{2:.6f}_v_loss_{3:.6f}'.format(mean_accr_t[-1], mean_accr_v[-1], 
                                                                                            mean_loss_t[-1], mean_loss_v[-1])
            saver.save(sess, './model/' + model_name + '_' + model_spec)
        if n_iter == 15000:
            break
#         if n_iter > 5000:
#             if np.max(accr_train) < 0.9:
#                 if np.mean(loss_train[-50:-30]) <= np.mean(loss_train[-30:]) :
#                     hist.early_under(n_iter)
#                     early_stopping = True
#                     break
#             if np.mean(accr_train[-50:]) >= 0.995:
#                 if (
#                     np.mean(loss_valid[-41:-21]) <= np.mean(loss_valid[-21:-1]) and
#                     loss_valid[-1] < loss_valid[-2] # np.min(loss_valid[-20:]) == loss_valid[-1]
#                     ):
#                     hist.early_over(n_iter)
#                     early_stopping = True
#                     break          
    
train_time = int((time.time() - start_time)/60)  
hist.done(n_iter, train_time, early_stopping)

hist.plot(cal_interval)   

# sess.close()
# Out:
# ==============================================================
# [Iter] || Train_accr || Valid_accr || Train_loss || Valid_loss
# ==============================================================
# W0122 11:02:15.922258 139675336218368 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# [*100] || 69.00 %    || 58.00 %    || 0.55739003 || 0.64155912
# --------------------------------------------------------------
# [*200] || 76.00 %    || 65.00 %    || 0.55901200 || 0.60549998
# --------------------------------------------------------------
# [*300] || 78.00 %    || 88.00 %    || 0.55072737 || 0.31781071
# --------------------------------------------------------------
# [*400] || 79.00 %    || 87.00 %    || 0.40275428 || 0.36802405
# --------------------------------------------------------------
# [*500] || 85.00 %    || 87.00 %    || 0.29311702 || 0.27262345
# --------------------------------------------------------------
# [*600] || 91.00 %    || 95.00 %    || 0.14151873 || 0.15263186
# --------------------------------------------------------------
# [*700] || 89.00 %    || 94.00 %    || 0.21813709 || 0.18259282
# --------------------------------------------------------------
# [*800] || 98.00 %    || 95.00 %    || 0.13166559 || 0.16603823
# --------------------------------------------------------------
# [*900] || 87.00 %    || 93.00 %    || 0.24777514 || 0.21955924
# --------------------------------------------------------------
